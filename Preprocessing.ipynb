# %%
import nltk

def read_ann_file(ann_file_path):
    annotations = []
    
    with open(ann_file_path, 'r',encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split('\t')  # Split by tab
            
            if len(parts) == 2:
                # Entity annotation (e.g., T1 background_claim 2417 2522 complicated)
                annotation_id, annotation_details = parts
                try:
                    entity_type, start, end, text = annotation_details.split()
                    annotations.append({
                        "id": annotation_id,
                        "type": entity_type,
                        "start": int(start),
                        "end": int(end),
                        "text": text
                    })
                except ValueError:
                    print(f"Skipping line due to unexpected format (Entity): {line.strip()}")
                    continue  # Skip this line
            
            elif len(parts) == 3:
                # Relation annotation (e.g., R1 supports Arg1:T4 Arg2:T5)
                annotation_id, relation_type, args = parts
                arguments = args.split()
                if len(arguments) != 2:
                    print(f"Skipping line due to unexpected argument count (Relation): {line.strip()}")
                    continue  # Skip this line
                
                # Split the arguments into pairs
                relation_args = {}
                for arg in arguments:
                    if ':' in arg:
                        key, value = arg.split(':')
                        relation_args[key] = value
                    else:
                        print(f"Skipping invalid argument (Relation): {arg}")
                        continue  # Skip invalid arguments
                
                annotations.append({
                    "id": annotation_id,
                    "relation_type": relation_type,
                    "arguments": relation_args
                })
    
    return annotations

# %%
file="A01.ann"
annotation=read_ann_file(file)
# Out:
# Skipping line due to unexpected argument count (Relation): T1	background_claim 2417 2522	complicated 3D character models are widely used in fields of entertainment, virtual reality, medicine etc
# Skipping line due to unexpected argument count (Relation): T2	background_claim 2524 2640	The range of breathtaking realistic 3D models is only limited by the creativity of artists and resolution of devices
# Skipping line due to unexpected argument count (Relation): T4	background_claim 2855 2897	a production cannot afford major revisions
# Skipping line due to unexpected argument count (Relation): T5	own_claim 2961 3041	providing a flexible and efficient solution to animation remains an open problem
# Skipping line due to unexpected format (Entity): R1	supports Arg1:T4 Arg2:T5
# Skipping line due to unexpected argument count (Relation): T6	background_claim 3211 3307	Skeleton Subspace Deformation (SSD) is the predominant approach to character skinning at present
# Skipping line due to unexpected argument count (Relation): T3	background_claim 2642 2709	Driving 3D models in a natural and believable manner is not trivial
# Skipping line due to unexpected argument count (Relation): T7	data 3433 3459	its ease of implementation
# Skipping line due to unexpected argument count (Relation): T8	data 3464 3485	low cost of computing
# Skipping line due to unexpected argument count (Relation): T9	background_claim 3349 3425	SSD is widely used in games, virtual reality and other realtime applications
# Skipping line due to unexpected format (Entity): R2	supports Arg1:T7 Arg2:T9
# Skipping line due to unexpected format (Entity): R3	supports Arg1:T8 Arg2:T9
# Skipping line due to unexpected argument count (Relation): T10	background_claim 3702 3787	artists will edit the geometry of characters in the rest pose to fine-tune animations
# Skipping line due to unexpected argument count (Relation): T11	background_claim 3789 3826	This approach is not commonly applied
# Skipping line due to unexpected argument count (Relation): T12	background_claim 3843 3899	editing in the rest pose will influence most other poses
# Skipping line due to unexpected format (Entity): R4	supports Arg1:T12 Arg2:T11
# Skipping line due to unexpected format (Entity): R5	contradicts Arg1:T11 Arg2:T10
# Skipping line due to unexpected argument count (Relation): T13	background_claim 3919 3991	SSD is also notorious for artifacts at rotating elbows and extreme poses
# Skipping line due to unexpected argument count (Relation): T14	background_claim 4186 4299	Example based skinning methods such as Pose Space Deformation (PSD) are candidates for correcting SSD limitations
# Skipping line due to unexpected argument count (Relation): T15	background_claim 4555 4610	PSD may be used as a compensation to the underlying SSD
# Skipping line due to unexpected argument count (Relation): T16	background_claim 4616 4688	the animator specifies the PSD examples after the SSD has been performed
# Skipping line due to unexpected argument count (Relation): T17	background_claim 4720 4804	the examples are best interpolated in the rest pose, before the SSD has been applied
# Skipping line due to unexpected format (Entity): R6	contradicts Arg1:T16 Arg2:T17
# Skipping line due to unexpected format (Entity): R7	contradicts Arg1:T15 Arg2:T17
# Skipping line due to unexpected argument count (Relation): T18	background_claim 4816 4949	the action of the SSD and any other deformations must be “inverted” in order to push the example compensation before these operations
# Skipping line due to unexpected format (Entity): R8	supports Arg1:T17 Arg2:T18
# Skipping line due to unexpected argument count (Relation): T19	background_claim 5264 5326	SSD is the most representative in the family of basic skinning
# Skipping line due to unexpected argument count (Relation): T20	own_claim 5510 5591	this inverse strategy has a better performance than the same framework without it
# Skipping line due to unexpected argument count (Relation): T21	own_claim 5866 5919	this approach will improve the quality of deformation
# Skipping line due to unexpected format (Entity): R9	semantically_same Arg1:T20 Arg2:T21
# Skipping line due to unexpected argument count (Relation): T22	background_claim 6489 6540	they are seldom applied to interactive applications
# Skipping line due to unexpected argument count (Relation): T23	data 6552 6578	the high cost of computing
# Skipping invalid argument (Relation): complicated
# Skipping invalid argument (Relation): algorithms
# Skipping line due to unexpected format (Entity): R10	supports Arg1:T23 Arg2:T22
# Skipping line due to unexpected format (Entity): R11	supports Arg1:T24 Arg2:T22
# Skipping line due to unexpected argument count (Relation): T25	background_claim 6385 6483	this category can generate more believable animation effects compared to its geometric counterpart
# Skipping line due to unexpected format (Entity): R12	contradicts Arg1:T22 Arg2:T25
# Skipping line due to unexpected argument count (Relation): T26	background_claim 6662 6684	Pose Space Deformation
# Skipping line due to unexpected argument count (Relation): T27	background_claim 6692 6855	combines shape blending and Skeleton Subspace Deformation by formulating a scattered data interpolation problem over sculpted (or otherwise obtained) example poses
# Skipping line due to unexpected format (Entity): R13	parts_of_same Arg1:T26 Arg2:T27
# Skipping line due to unexpected argument count (Relation): T28	data 6686 6691	[ 1 ]
# Skipping line due to unexpected format (Entity): R14	supports Arg1:T28 Arg2:T27
# Skipping line due to unexpected argument count (Relation): T29	background_claim 7666 7750	Related research efforts have improved the speed and power of example-based skinning
# Skipping line due to unexpected argument count (Relation): T30	background_claim 7759 7840	incorporate linear elements into RBF to produce constant changes between examples
# Skipping line due to unexpected argument count (Relation): T31	data 7752 7757	[ 2 ]
# Skipping line due to unexpected format (Entity): R15	supports Arg1:T31 Arg2:T30
# Skipping line due to unexpected format (Entity): R16	supports Arg1:T30 Arg2:T29
# Skipping line due to unexpected argument count (Relation): T32	background_claim 7848 7988	precompute principal components of the deformation influences for individual kinematic joints instead of storing displacements for key poses
# Skipping line due to unexpected argument count (Relation): T33	background_claim 7998 8078	enabling realtime rendering large nonlinear finite element models of human hands
# Skipping line due to unexpected argument count (Relation): T34	data 7842 7847	[ 3 ]
# Skipping line due to unexpected format (Entity): R17	supports Arg1:T34 Arg2:T32
# Skipping line due to unexpected format (Entity): R18	supports Arg1:T32 Arg2:T33
# Skipping line due to unexpected format (Entity): R19	supports Arg1:T33 Arg2:T29
# Skipping line due to unexpected argument count (Relation): T35	background_claim 8086 8172	introduce weighted pose space deformation for deforming realistic models of human hand
# Skipping line due to unexpected argument count (Relation): T36	data 8080 8085	[ 4 ]
# Skipping line due to unexpected format (Entity): R20	supports Arg1:T36 Arg2:T35
# Skipping line due to unexpected format (Entity): R21	supports Arg1:T35 Arg2:T29
# Skipping line due to unexpected argument count (Relation): T37	background_claim 8356 8447	these example-based approaches can be considered as non-parametric skin deformation methods
# Skipping line due to unexpected argument count (Relation): T38	background_claim 8196 8297	identifies statistically relevant bones and approximates bone transforms from example mesh animations
# Skipping line due to unexpected argument count (Relation): T39	data 8190 8195	[ 5 ]
# Skipping line due to unexpected format (Entity): R22	supports Arg1:T39 Arg2:T38
# Skipping line due to unexpected format (Entity): R23	supports Arg1:T38 Arg2:T29
# Skipping line due to unexpected argument count (Relation): T40	background_claim 8684 8737	these have also seen some development in recent years
# Skipping line due to unexpected argument count (Relation): T41	data 8738 8743	[ 6 ]
# Skipping line due to unexpected argument count (Relation): T42	data 8745 8750	[ 7 ]
# Skipping line due to unexpected format (Entity): R24	supports Arg1:T41 Arg2:T40
# Skipping line due to unexpected format (Entity): R25	supports Arg1:T42 Arg2:T40
# Skipping line due to unexpected argument count (Relation): T43	background_claim 8870 8927	are also common practices in the entertainment production
# Skipping line due to unexpected argument count (Relation): T44	background_claim 8752 8785	Skinning using free form lattices
# Skipping invalid argument (Relation): NURBS
# Skipping invalid argument (Relation): curves
# Skipping line due to unexpected format (Entity): R26	parts_of_same Arg1:T44 Arg2:T45
# Skipping line due to unexpected format (Entity): R27	parts_of_same Arg1:T43 Arg2:T45
# Skipping line due to unexpected argument count (Relation): T46	data 8815 8821	[ 10 ]
# Skipping line due to unexpected argument count (Relation): T47	data 8786 8791	[ 8 ]
# Skipping line due to unexpected argument count (Relation): T48	data 8793 8798	[ 9 ]
# Skipping line due to unexpected format (Entity): R28	supports Arg1:T47 Arg2:T44
# Skipping line due to unexpected format (Entity): R29	supports Arg1:T48 Arg2:T44
# Skipping line due to unexpected format (Entity): R30	supports Arg1:T46 Arg2:T45
# Skipping line due to unexpected argument count (Relation): T49	own_claim 9263 9308	the inverse operation can improve the results
# Skipping line due to unexpected argument count (Relation): T50	own_claim 9590 9619	inverse operation is required
# Skipping line due to unexpected format (Entity): R31	semantically_same Arg1:T49 Arg2:T21
# Skipping line due to unexpected argument count (Relation): T51	background_claim 10442 10525	SSD is widely applied to interactive applications such as games and virtual reality
# Skipping line due to unexpected argument count (Relation): T52	background_claim 10531 10586	it is implemented in most commercial animation packages
# Skipping invalid argument (Relation): its
# Skipping invalid argument (Relation): simplicity
# Skipping line due to unexpected argument count (Relation): T54	data 10430 10440	efficiency
# Skipping line due to unexpected format (Entity): R32	supports Arg1:T54 Arg2:T51
# Skipping line due to unexpected format (Entity): R33	supports Arg1:T53 Arg2:T51
# Skipping line due to unexpected format (Entity): R34	supports Arg1:T54 Arg2:T52
# Skipping line due to unexpected format (Entity): R35	supports Arg1:T53 Arg2:T52
# Skipping line due to unexpected argument count (Relation): T55	background_claim 12084 12179	SSD is very popular in circumstances that require animating a number of characters in real time
# Skipping line due to unexpected argument count (Relation): T56	data 12014 12082	vertex transformations can be easily implemented in the graphic card
# Skipping line due to unexpected format (Entity): R36	supports Arg1:T56 Arg2:T55
# Skipping line due to unexpected argument count (Relation): T57	background_claim 12335 12494	the domain of adjusting one vertex in this way is strictly limited to the linear subspace formed by the vertex as transformed by joints influencing this vertex
# Skipping line due to unexpected argument count (Relation): T58	background_claim 12243 12329	When a character goes wrong in some pose, animators can adjust joint influence weights
# Skipping line due to unexpected format (Entity): R37	contradicts Arg1:T57 Arg2:T58
# Skipping line due to unexpected argument count (Relation): T59	background_claim 12741 12832	SSD cannot synthesize many parts of a character skin involving complicated joint structures
# Skipping line due to unexpected argument count (Relation): T60	background_claim 12671 12712	deforming is limited to a linear subspace
# Skipping line due to unexpected argument count (Relation): T61	data 12634 12639	[ 1 ]
# Skipping line due to unexpected format (Entity): R38	supports Arg1:T61 Arg2:T60
# Skipping line due to unexpected format (Entity): R39	supports Arg1:T60 Arg2:T59
# Skipping line due to unexpected argument count (Relation): T62	background_claim 12917 13008	a combination of SSD and shape blending providing nice solution to above mentioned problems
# Skipping line due to unexpected argument count (Relation): T63	data 12908 12913	[ 1 ]
# Skipping line due to unexpected format (Entity): R40	supports Arg1:T63 Arg2:T62
# Skipping line due to unexpected argument count (Relation): T64	background_claim 14983 15062	PSD and improved example-based schemes have been discussed in many publications
# Skipping line due to unexpected argument count (Relation): T65	data 15064 15069	[ 2 ]
# Skipping line due to unexpected argument count (Relation): T66	data 15071 15076	[ 3 ]
# Skipping line due to unexpected argument count (Relation): T67	data 15078 15083	[ 4 ]
# Skipping line due to unexpected argument count (Relation): T68	own_claim 15086 15151	the reason why the inverse should be performed is still ambiguous
# Skipping line due to unexpected format (Entity): R41	supports Arg1:T65 Arg2:T64
# Skipping line due to unexpected format (Entity): R42	supports Arg1:T66 Arg2:T64
# Skipping line due to unexpected format (Entity): R43	supports Arg1:T67 Arg2:T64
# Skipping line due to unexpected format (Entity): R44	contradicts Arg1:T64 Arg2:T68
# Skipping line due to unexpected argument count (Relation): T69	own_claim 15220 15338	inverting the SSD (and other deformations) in order to interpolate the examples in the rest pose is a the right choice
# Skipping line due to unexpected format (Entity): R45	semantically_same Arg1:T69 Arg2:T50
# Skipping line due to unexpected argument count (Relation): T70	own_claim 15478 15498	it is an improvement
# Skipping line due to unexpected format (Entity): R46	semantically_same Arg1:T70 Arg2:T69
# Skipping line due to unexpected argument count (Relation): T71	own_claim 15754 15791	the superiority of the inverse method
# Skipping line due to unexpected format (Entity): R47	semantically_same Arg1:T71 Arg2:T70
# Skipping line due to unexpected format (Entity): R48	semantically_same Arg1:T50 Arg2:T49
# Skipping line due to unexpected argument count (Relation): T72	own_claim 16991 17058	SSD −1 simply is the inverse transformation matrix generated by SSD
# Skipping line due to unexpected argument count (Relation): T73	data 16963 16989	SSD is a 3D transformation
# Skipping line due to unexpected format (Entity): R49	supports Arg1:T73 Arg2:T72
# Skipping line due to unexpected argument count (Relation): T74	own_claim 17950 17980	the inverse method is superior
# Skipping line due to unexpected format (Entity): R50	semantically_same Arg1:T74 Arg2:T71
# Skipping line due to unexpected argument count (Relation): T75	background_claim 19098 19196	Taking the model in rest pose as an example is a common practice when applying shape interpolation
# Skipping line due to unexpected argument count (Relation): T76	background_claim 19204 19295	interpolating effects from other examples should not change the original model in rest pose
# Skipping line due to unexpected format (Entity): R51	supports Arg1:T76 Arg2:T75
# Skipping line due to unexpected argument count (Relation): T77	own_claim 19334 19603	we have: ω 1x = φ 11 −1 d 1x + φ 12 −1 d 2x = φ 12 −1 d 2x ω 2x = φ 21 −1 d 1x + φ 22 −1 d 2x = φ 22 −1 d 2x = d 2x ω 1y = φ 11 −1 d 1y + φ 12 −1 d 2y = φ 12 −1 d 2y ω 2y = φ 21 −1 d 1y + φ 22 −1 d 2y = φ 22 −1 d 2y = d 2y where φ i −1 j is the (i, j)th element of Φ −1
# Skipping line due to unexpected format (Entity): R52	supports Arg1:T75 Arg2:T77
# Skipping line due to unexpected argument count (Relation): T78	own_claim 20353 20469	we simplify SSD as a rotation transformation ignoring other issues such as accumulating effects from the first joint
# Skipping line due to unexpected argument count (Relation): T79	own_claim 20318 20351	only the second joint is rotating
# Skipping line due to unexpected format (Entity): R53	supports Arg1:T79 Arg2:T78
# Skipping line due to unexpected argument count (Relation): T80	own_claim 21667 21764	in forward case, the direction of deformed vertex always keeps the same with the example cylinder
# Skipping line due to unexpected argument count (Relation): T81	data 21765 21777	( figure 4 )
# Skipping line due to unexpected format (Entity): R54	supports Arg1:T81 Arg2:T80
# Skipping line due to unexpected argument count (Relation): T82	own_claim 21779 21866	For inverse PSD however, that direction is changed along with the rotation of the joint
# Skipping line due to unexpected format (Entity): R55	supports Arg1:T81 Arg2:T82
# Skipping line due to unexpected argument count (Relation): T83	own_claim 22106 22158	PSD is supposed to be a method as “local” correction
# Skipping line due to unexpected argument count (Relation): T84	own_claim 22172 22269	pose space should not be extended to a whole space that has to incorporate all influenced objects
# Skipping line due to unexpected format (Entity): R56	supports Arg1:T83 Arg2:T84
# Skipping line due to unexpected argument count (Relation): T85	data 22082 22104	a matter of experience
# Skipping line due to unexpected format (Entity): R57	supports Arg1:T85 Arg2:T83
# Skipping line due to unexpected argument count (Relation): T86	own_claim 22282 22353	large amount of unnecessary works of building examples will be required
# Skipping line due to unexpected argument count (Relation): T87	own_claim 22359 22415	the distance between different poses is also meaningless
# Skipping line due to unexpected format (Entity): R58	supports Arg1:T86 Arg2:T84
# Skipping line due to unexpected format (Entity): R59	supports Arg1:T87 Arg2:T84
# Skipping line due to unexpected argument count (Relation): T88	background_claim 23066 23128	most of which have been implemented in most animation packages
# Skipping line due to unexpected argument count (Relation): T89	background_claim 22985 23049	in many circumstances, other deformation schemes will be adopted
# Skipping line due to unexpected argument count (Relation): T90	data 23058 23064	[ 10 ]
# Skipping line due to unexpected argument count (Relation): T91	data 23051 23056	[ 9 ]
# Skipping line due to unexpected format (Entity): R60	supports Arg1:T90 Arg2:T89
# Skipping line due to unexpected format (Entity): R61	supports Arg1:T91 Arg2:T89
# Skipping line due to unexpected argument count (Relation): T92	own_claim 23289 23371	we can deform the original character model from rest pose to another specific pose
# Skipping line due to unexpected argument count (Relation): T93	background_claim 25039 25152	One advantage of Powell’s classic method is that it does not need explicit computation of the function’s gradient
# Skipping line due to unexpected argument count (Relation): T94	data 25154 25160	[ 12 ]
# Skipping line due to unexpected format (Entity): R62	supports Arg1:T94 Arg2:T93
# Skipping line due to unexpected argument count (Relation): T95	own_claim 25264 25291	Powell’s method is suitable
# Skipping line due to unexpected argument count (Relation): T96	data 25170 25259	we are treating the skinning operations as a “black box”, their gradient is not available
# Skipping line due to unexpected format (Entity): R63	supports Arg1:T96 Arg2:T95
# Skipping line due to unexpected argument count (Relation): T97	background_claim 25659 25789	after repeated cycles of M line minimizations on conjugate directions, the optimization will in due course converge to the minimum
# Skipping line due to unexpected argument count (Relation): T98	data 25790 25796	[ 12 ]
# Skipping line due to unexpected format (Entity): R64	supports Arg1:T98 Arg2:T97
# Skipping line due to unexpected argument count (Relation): T99	own_claim 26918 27029	If the SSD transformation in equation 1 is singular, some types of inverse PSD deformation will not be possible
# Skipping line due to unexpected argument count (Relation): T100	data 27039 27141	any component of the desired deformation that lies in the null space of the SSD matrix will be ignored
# Skipping line due to unexpected format (Entity): R65	supports Arg1:T100 Arg2:T99
# Skipping line due to unexpected argument count (Relation): T101	own_claim 27152 27175	singular cases are rare
# Skipping line due to unexpected argument count (Relation): T102	own_claim 27324 27415	it is possible to handle these cases with a small rearrangement of the inverse PSD approach
# Skipping line due to unexpected argument count (Relation): T103	data 27177 27321	one example is a joint with 180 o rotation and equal 2 1 , 2 1 weights on the two joint frames, which is an unrealistic case of selfintersection
# Skipping line due to unexpected format (Entity): R66	supports Arg1:T103 Arg2:T101
# Skipping line due to unexpected format (Entity): R67	contradicts Arg1:T99 Arg2:T102
# Skipping line due to unexpected argument count (Relation): T104	own_claim 27847 27875	it will be generally be zero
# Skipping line due to unexpected argument count (Relation): T105	data 27823 27845	w i is being minimized
# Skipping line due to unexpected format (Entity): R68	supports Arg1:T105 Arg2:T104
# Skipping line due to unexpected argument count (Relation): T106	own_claim 27881 27992	will be non-zero only if it is not possible to obtain the desired deformation v i using SKINNING i (v r + d i )
# Skipping line due to unexpected format (Entity): R69	supports Arg1:T105 Arg2:T106
# Skipping line due to unexpected argument count (Relation): T107	own_claim 28651 28742	Inverse skinning integrates SSD and shape interpolation more firmly than its forward rival.
# Skipping line due to unexpected argument count (Relation): T108	own_claim 28960 29042	the inverse approach presents better performance and more consistent interpolation
# Skipping line due to unexpected argument count (Relation): T109	data 29045 29066	Figure 7 to Figure 10
# Skipping line due to unexpected format (Entity): R70	supports Arg1:T109 Arg2:T108
# Skipping line due to unexpected argument count (Relation): T110	own_claim 28758 28948	the direction of deformed vertex in inverse skinning is linearly proportional to joint rotations in a simplified example, while the forward PSD does not incorporate the direction information
# Skipping line due to unexpected format (Entity): R71	supports Arg1:T110 Arg2:T108
# Skipping line due to unexpected format (Entity): R72	semantically_same Arg1:T108 Arg2:T74
# Skipping line due to unexpected argument count (Relation): T111	own_claim 29268 29315	the minimizing process will introduce more cost
# Skipping line due to unexpected argument count (Relation): T112	own_claim 29640 29689	The cost of the inverse operation is not critical
# Skipping line due to unexpected argument count (Relation): T113	own_claim 29706 29735	it is a one time “setup” cost
# Skipping line due to unexpected argument count (Relation): T114	own_claim 29741 29845	the compute time is insignificant compared to the human time required to sculpt the desired deformations
# Skipping line due to unexpected format (Entity): R73	supports Arg1:T113 Arg2:T112
# Skipping line due to unexpected format (Entity): R74	supports Arg1:T114 Arg2:T112
# Skipping line due to unexpected argument count (Relation): T115	data 2835 2853	a frame goes wrong
# Skipping line due to unexpected format (Entity): R75	supports Arg1:T115 Arg2:T4
# Skipping line due to unexpected format (Entity): R76	semantically_same Arg1:T14 Arg2:T15
# Skipping invalid argument (Relation): physical
# Skipping invalid argument (Relation): principles
# Skipping line due to unexpected format (Entity): R77	supports Arg1:T116 Arg2:T25
# Skipping line due to unexpected argument count (Relation): T117	data 2727 2753	the model is very detailed
# Skipping line due to unexpected argument count (Relation): T118	data 2758 2818	playback of animation becomes quite heavy and time consuming
# Skipping line due to unexpected format (Entity): R78	supports Arg1:T117 Arg2:T3
# Skipping line due to unexpected format (Entity): R79	supports Arg1:T118 Arg2:T3
# Skipping line due to unexpected format (Entity): R80	supports Arg1:T9 Arg2:T6
# Skipping line due to unexpected argument count (Relation): T119	background_claim 3993 4044	For those applications that require visual fidelity
# Skipping line due to unexpected argument count (Relation): T120	background_claim 4062 4098	SSD serves only as a basic framework
# Skipping line due to unexpected format (Entity): R81	parts_of_same Arg1:T119 Arg2:T120
# Skipping line due to unexpected argument count (Relation): T121	background_claim 4439 4535	PSD smoothly interpolates these meshes in pose space and produces visually attractive animations
# Skipping line due to unexpected argument count (Relation): T122	background_claim 4951 4989	Besides SSD, other skinning approaches
# Skipping line due to unexpected argument count (Relation): T123	background_claim 5041 5060	can also be applied
# Skipping invalid argument (Relation): rigid
# Skipping invalid argument (Relation): skinning
# Skipping line due to unexpected argument count (Relation): T125	data 5014 5035	Free Form Deformation
# Skipping line due to unexpected format (Entity): R82	parts_of_same Arg1:T122 Arg2:T123
# Skipping line due to unexpected format (Entity): R83	supports Arg1:T124 Arg2:T122
# Skipping line due to unexpected format (Entity): R84	supports Arg1:T125 Arg2:T122
# Skipping line due to unexpected argument count (Relation): T126	background_claim 6265 6356	physical modelling and animation is another field providing realistic character simulations
# Skipping line due to unexpected argument count (Relation): T127	background_claim 8578 8682	Simpler parametric skinning approaches (of which SSD is the prototype) have a fixed number of parameters
# Skipping line due to unexpected format (Entity): R85	supports Arg1:T41 Arg2:T127
# Skipping line due to unexpected format (Entity): R86	supports Arg1:T42 Arg2:T127
# Skipping line due to unexpected argument count (Relation): T128	own_claim 9346 9441	the direction of deformed vertices from inverse skinning is a linear function of joint rotation
# Skipping line due to unexpected argument count (Relation): T129	own_claim 9449 9510	in the forward approach, that direction is kept as a constant
# Skipping line due to unexpected format (Entity): R87	contradicts Arg1:T129 Arg2:T128
# Skipping line due to unexpected argument count (Relation): T130	own_claim 9695 9848	propose a unified framework which can be implemented on high-end commercial packages while allowing any proprietary skinning operators to be incorporated
# Skipping line due to unexpected argument count (Relation): T131	background_claim 10115 10276	Skeleton Subspace Deformation (SSD) is a basic algorithm that is used to define how the character surface deforms following movements of its underlying skeletons
# Skipping line due to unexpected argument count (Relation): T132	data 10309 10315	[ 11 ]
# Skipping line due to unexpected format (Entity): R88	supports Arg1:T132 Arg2:T131
# Skipping line due to unexpected argument count (Relation): T133	data 10949 10987	SSD is adopted to define this relation
# Skipping line due to unexpected argument count (Relation): T134	background_claim 10989 11158	each vertex or control point of the character surface is provided with a list of joints, that will influence it, along with the weight indicating the amount of influence
# Skipping line due to unexpected format (Entity): R89	supports Arg1:T133 Arg2:T134
# Skipping line due to unexpected argument count (Relation): T135	background_claim 11192 11326	the position of a vertex in the animated pose is the result of weighted linear blending of its transformation by each associated joint
# Skipping line due to unexpected argument count (Relation): T136	data 11165 11190	the character is animated
# Skipping line due to unexpected format (Entity): R90	supports Arg1:T136 Arg2:T135
# Skipping line due to unexpected argument count (Relation): T137	background_claim 12572 12615	The famous SSD problem of “collapsed elbow”
# Skipping line due to unexpected format (Entity): R91	supports Arg1:T60 Arg2:T137
# Skipping line due to unexpected argument count (Relation): T138	data 13915 13942	sculpted in N example poses
# Skipping line due to unexpected argument count (Relation): T139	data 13900 13910	a vertex v
# Skipping line due to unexpected format (Entity): R92	parts_of_same Arg1:T139 Arg2:T138
# Skipping line due to unexpected argument count (Relation): T140	own_claim 13949 14047	there are N delta d i , i = 0, . . . , N − 1 corresponding to each pose x i , i = 0, . . . , N − 1
# Skipping line due to unexpected format (Entity): R93	supports Arg1:T138 Arg2:T140
# Skipping line due to unexpected argument count (Relation): T141	own_claim 15515 15545	SSD as the underlying skinning
# Skipping line due to unexpected argument count (Relation): T142	own_claim 15553 15632	an explicit form of basic skinning can help to simplify our task of explanation
# Skipping line due to unexpected format (Entity): R94	supports Arg1:T142 Arg2:T141
# Skipping line due to unexpected argument count (Relation): T143	data 19004 19059	in the rest pose, we didn’t generate any movement for v
# Skipping line due to unexpected argument count (Relation): T144	own_claim 19067 19096	d 1 = [d 1x , d 1y ] = [0, 0]
# Skipping line due to unexpected format (Entity): R95	supports Arg1:T143 Arg2:T144
# Skipping line due to unexpected argument count (Relation): T145	data 19308 19333	by solving above equation
# Skipping line due to unexpected format (Entity): R96	supports Arg1:T145 Arg2:T77
# Skipping line due to unexpected argument count (Relation): T146	data 19613 19618	i = j
# Skipping line due to unexpected argument count (Relation): T147	own_claim 19620 19632	φ i −1 j = 1
# Skipping line due to unexpected format (Entity): R97	supports Arg1:T146 Arg2:T147
# Skipping line due to unexpected argument count (Relation): T148	own_claim 20030 20137	this angle α p is a constant and depends only on the value of delta in the second pose d 2 = [d 2x , d 2y ]
# Skipping line due to unexpected argument count (Relation): T149	own_claim 19817 20018	tan α p = d d x y = ω ω 1x 1y φ φ (x (x − − x x 1 1 ) ) + + ω ω 2y 2x φ φ (x (x − − x x 2 2 ) ) = φ φ 12 12 −1 −1 d d 2x 2y φ φ (x (x − − x x 1 1 ) ) + + d d 2x 2y φ φ (x (x − − x x 2 2 ) ) = d 2y d 2x
# Skipping line due to unexpected format (Entity): R98	supports Arg1:T149 Arg2:T148
# Skipping line due to unexpected argument count (Relation): T150	own_claim 19683 19700	tan α p = d d x y
# Skipping line due to unexpected format (Entity): R99	supports Arg1:T150 Arg2:T149
# Skipping line due to unexpected argument count (Relation): T151	own_claim 21868 21920	The case described above is quite common in practice
# Skipping line due to unexpected argument count (Relation): T152	data 21926 21973	animating shoulder, elbow, knee, hip-bone, neck
# Skipping line due to unexpected format (Entity): R100	supports Arg1:T152 Arg2:T151
# Skipping line due to unexpected argument count (Relation): T153	own_claim 21980 22058	All these parts would rotate from the rest pose with some angle to other poses
# Skipping line due to unexpected argument count (Relation): T154	own_claim 23151 23225	a unified framework in which no explicit inverse operation is necessitated
# Skipping line due to unexpected format (Entity): R101	supports Arg1:T88 Arg2:T154
# Skipping line due to unexpected argument count (Relation): T155	data 23233 23288	a basic skinning method supported by animation packages
# Skipping line due to unexpected format (Entity): R102	supports Arg1:T155 Arg2:T92
# Skipping line due to unexpected argument count (Relation): T156	own_claim 23494 23537	v i t = v i + d i = SKINNING i (v r ) + d i
# Skipping line due to unexpected argument count (Relation): T157	own_claim 23399 23492	we need to replace SSD with SKINNING in the inverse skinning algorithm as such for equation 4
# Skipping line due to unexpected argument count (Relation): T158	data 23376 23397	the more general case
# Skipping line due to unexpected format (Entity): R103	supports Arg1:T158 Arg2:T157
# Skipping line due to unexpected format (Entity): R104	supports Arg1:T157 Arg2:T156
# Skipping line due to unexpected argument count (Relation): T159	own_claim 23613 23765	To find delta d i in the rest pose: v i = SKINNING i (v r ) + d i = SKINNING i (v r + d i ) we can setup a minimization problem to minimize the function
# Skipping line due to unexpected argument count (Relation): T160	own_claim 24028 24110	This function can be given to Powell’s method to find d i at the minimum of f (d )
# Skipping line due to unexpected argument count (Relation): T161	data 24112 24153	For each example pose P i , we have a d i
# Skipping line due to unexpected argument count (Relation): T162	own_claim 24161 24270	we can apply radial basis function to d i (i = 0 . . . n − 1) in pose space to obtain ω i (i = 0 . . . n − 1)
# Skipping line due to unexpected format (Entity): R105	supports Arg1:T161 Arg2:T162
# Skipping line due to unexpected argument count (Relation): T163	own_claim 25293 25398	Minimizing the function f (d ) in a particular direction is actually minimization problem of one variable
# Skipping line due to unexpected argument count (Relation): T164	background_claim 25440 25556	Powell’s idea is trying to find each minimum of function f (d ) in different direction until f (d ) stops decreasing
# Skipping line due to unexpected argument count (Relation): T165	background_claim 25558 25629	How to choose the next direction is the main concern of Powell’s method
# Skipping line due to unexpected argument count (Relation): T166	background_claim 26052 26159	In Maya, “tweaking” is a procedure adding delta values to original surface vertices before any deformations
# Skipping line due to unexpected argument count (Relation): T167	background_claim 26161 26251	It is actu- ally Maya’s form of rest-pose editing for their built-in deformation operators
# Skipping line due to unexpected argument count (Relation): T168	own_claim 26280 26323	the whole system is divided into two phases
# Skipping invalid argument (Relation): Figure
# Skipping invalid argument (Relation): 6
# Skipping line due to unexpected format (Entity): R106	supports Arg1:T169 Arg2:T168
# Skipping line due to unexpected argument count (Relation): T170	own_claim 26325 26414	The first phase is to find each delta in the rest pose corresponding to each example pose
# Skipping line due to unexpected format (Entity): R107	supports Arg1:T170 Arg2:T168
# Skipping line due to unexpected argument count (Relation): T171	own_claim 26570 26665	the second phase that is a linear system performing RBF interpolation to obtain the PSD weights
# Skipping line due to unexpected format (Entity): R108	supports Arg1:T171 Arg2:T168
# Skipping line due to unexpected argument count (Relation): T172	own_claim 27753 27791	only minimal code changed are required
# Skipping line due to unexpected argument count (Relation): T173	own_claim 27596 27745	The final synthesis is then v x = SKINNING(v r + d x ) + w x where w x is interpolated after SKINNING by applying the same RBF scheme as used for d x
# Skipping line due to unexpected format (Entity): R109	supports Arg1:T173 Arg2:T172
# Skipping line due to unexpected argument count (Relation): T174	data 28012 28045	the SSD transform is nearsingular
# Skipping line due to unexpected argument count (Relation): T175	own_claim 28047 28143	the solved d i can be much large than other d k , which can result in poorly posed interpolation
# Skipping line due to unexpected format (Entity): R110	supports Arg1:T174 Arg2:T175
# Skipping line due to unexpected argument count (Relation): T176	own_claim 29881 29918	the synthesis is potentially realtime
# Skipping line due to unexpected argument count (Relation): T177	own_claim 29925 29971	no extra computing is involved in this process
# Skipping line due to unexpected format (Entity): R111	supports Arg1:T177 Arg2:T176
# Skipping line due to unexpected argument count (Relation): T178	data 29852 29879	the linear system is solved
# Skipping line due to unexpected format (Entity): R112	supports Arg1:T178 Arg2:T176
# Skipping line due to unexpected argument count (Relation): T179	data 5433 5493	only one joint rotation and two example poses are considered
# Skipping line due to unexpected format (Entity): R113	supports Arg1:T179 Arg2:T20
# Skipping line due to unexpected argument count (Relation): T180	background_claim 3309 3338	A nice review of SSD is given
# Skipping line due to unexpected argument count (Relation): T181	data 3344 3345	1
# Skipping line due to unexpected format (Entity): R114	supports Arg1:T181 Arg2:T180
# Skipping invalid argument (Relation): resculpting
# Skipping invalid argument (Relation): models
# Skipping line due to unexpected format (Entity): R115	supports Arg1:T182 Arg2:T4
# Skipping invalid argument (Relation): re-rigging
# Skipping invalid argument (Relation): skeletons
# Skipping line due to unexpected format (Entity): R116	supports Arg1:T183 Arg2:T4

# %%
import nltk

def read_ann_file(ann_file_path):
    annotations = []
    
    with open(ann_file_path, 'r',encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split('\t')  # Split by tab
            
            if len(parts) == 2:
                # Entity annotation (e.g., T1 background_claim 2417 2522 complicated)
                annotation_id, annotation_details = parts
                try:
                    entity_type, start, end, text = annotation_details.split()
                    annotations.append({
                        "id": annotation_id,
                        "type": entity_type,
                        "start": int(start),
                        "end": int(end),
                        "text": text
                    })
                except ValueError:
                    print(f"Skipping line due to unexpected format (Entity): {line.strip()}")
                    continue  # Skip this line
            
            elif len(parts) == 3:
                # Relation annotation (e.g., R1 supports Arg1:T4 Arg2:T5)
                annotation_id, relation_type, args = parts
                arguments = args.split()
                if len(arguments) != 2:
                    print(f"Skipping line due to unexpected argument count (Relation): {line.strip()}")
                    continue  # Skip this line
                
                # Split the arguments into pairs
                relation_args = {}
                for arg in arguments:
                    if ':' in arg:
                        key, value = arg.split(':')
                        relation_args[key] = value
                    else:
                        print(f"Skipping invalid argument (Relation): {arg}")
                        continue  # Skip invalid arguments
                
                annotations.append({
                    "id": annotation_id,
                    "relation_type": relation_type,
                    "arguments": relation_args
                })
    
    return annotations

# %%
file="A01.ann"
annotation=read_ann_file(file)
# Out:
# Skipping line due to unexpected argument count (Relation): T1	background_claim 2417 2522	complicated 3D character models are widely used in fields of entertainment, virtual reality, medicine etc
# Skipping line due to unexpected argument count (Relation): T2	background_claim 2524 2640	The range of breathtaking realistic 3D models is only limited by the creativity of artists and resolution of devices
# Skipping line due to unexpected argument count (Relation): T4	background_claim 2855 2897	a production cannot afford major revisions
# Skipping line due to unexpected argument count (Relation): T5	own_claim 2961 3041	providing a flexible and efficient solution to animation remains an open problem
# Skipping line due to unexpected format (Entity): R1	supports Arg1:T4 Arg2:T5
# Skipping line due to unexpected argument count (Relation): T6	background_claim 3211 3307	Skeleton Subspace Deformation (SSD) is the predominant approach to character skinning at present
# Skipping line due to unexpected argument count (Relation): T3	background_claim 2642 2709	Driving 3D models in a natural and believable manner is not trivial
# Skipping line due to unexpected argument count (Relation): T7	data 3433 3459	its ease of implementation
# Skipping line due to unexpected argument count (Relation): T8	data 3464 3485	low cost of computing
# Skipping line due to unexpected argument count (Relation): T9	background_claim 3349 3425	SSD is widely used in games, virtual reality and other realtime applications
# Skipping line due to unexpected format (Entity): R2	supports Arg1:T7 Arg2:T9
# Skipping line due to unexpected format (Entity): R3	supports Arg1:T8 Arg2:T9
# Skipping line due to unexpected argument count (Relation): T10	background_claim 3702 3787	artists will edit the geometry of characters in the rest pose to fine-tune animations
# Skipping line due to unexpected argument count (Relation): T11	background_claim 3789 3826	This approach is not commonly applied
# Skipping line due to unexpected argument count (Relation): T12	background_claim 3843 3899	editing in the rest pose will influence most other poses
# Skipping line due to unexpected format (Entity): R4	supports Arg1:T12 Arg2:T11
# Skipping line due to unexpected format (Entity): R5	contradicts Arg1:T11 Arg2:T10
# Skipping line due to unexpected argument count (Relation): T13	background_claim 3919 3991	SSD is also notorious for artifacts at rotating elbows and extreme poses
# Skipping line due to unexpected argument count (Relation): T14	background_claim 4186 4299	Example based skinning methods such as Pose Space Deformation (PSD) are candidates for correcting SSD limitations
# Skipping line due to unexpected argument count (Relation): T15	background_claim 4555 4610	PSD may be used as a compensation to the underlying SSD
# Skipping line due to unexpected argument count (Relation): T16	background_claim 4616 4688	the animator specifies the PSD examples after the SSD has been performed
# Skipping line due to unexpected argument count (Relation): T17	background_claim 4720 4804	the examples are best interpolated in the rest pose, before the SSD has been applied
# Skipping line due to unexpected format (Entity): R6	contradicts Arg1:T16 Arg2:T17
# Skipping line due to unexpected format (Entity): R7	contradicts Arg1:T15 Arg2:T17
# Skipping line due to unexpected argument count (Relation): T18	background_claim 4816 4949	the action of the SSD and any other deformations must be “inverted” in order to push the example compensation before these operations
# Skipping line due to unexpected format (Entity): R8	supports Arg1:T17 Arg2:T18
# Skipping line due to unexpected argument count (Relation): T19	background_claim 5264 5326	SSD is the most representative in the family of basic skinning
# Skipping line due to unexpected argument count (Relation): T20	own_claim 5510 5591	this inverse strategy has a better performance than the same framework without it
# Skipping line due to unexpected argument count (Relation): T21	own_claim 5866 5919	this approach will improve the quality of deformation
# Skipping line due to unexpected format (Entity): R9	semantically_same Arg1:T20 Arg2:T21
# Skipping line due to unexpected argument count (Relation): T22	background_claim 6489 6540	they are seldom applied to interactive applications
# Skipping line due to unexpected argument count (Relation): T23	data 6552 6578	the high cost of computing
# Skipping invalid argument (Relation): complicated
# Skipping invalid argument (Relation): algorithms
# Skipping line due to unexpected format (Entity): R10	supports Arg1:T23 Arg2:T22
# Skipping line due to unexpected format (Entity): R11	supports Arg1:T24 Arg2:T22
# Skipping line due to unexpected argument count (Relation): T25	background_claim 6385 6483	this category can generate more believable animation effects compared to its geometric counterpart
# Skipping line due to unexpected format (Entity): R12	contradicts Arg1:T22 Arg2:T25
# Skipping line due to unexpected argument count (Relation): T26	background_claim 6662 6684	Pose Space Deformation
# Skipping line due to unexpected argument count (Relation): T27	background_claim 6692 6855	combines shape blending and Skeleton Subspace Deformation by formulating a scattered data interpolation problem over sculpted (or otherwise obtained) example poses
# Skipping line due to unexpected format (Entity): R13	parts_of_same Arg1:T26 Arg2:T27
# Skipping line due to unexpected argument count (Relation): T28	data 6686 6691	[ 1 ]
# Skipping line due to unexpected format (Entity): R14	supports Arg1:T28 Arg2:T27
# Skipping line due to unexpected argument count (Relation): T29	background_claim 7666 7750	Related research efforts have improved the speed and power of example-based skinning
# Skipping line due to unexpected argument count (Relation): T30	background_claim 7759 7840	incorporate linear elements into RBF to produce constant changes between examples
# Skipping line due to unexpected argument count (Relation): T31	data 7752 7757	[ 2 ]
# Skipping line due to unexpected format (Entity): R15	supports Arg1:T31 Arg2:T30
# Skipping line due to unexpected format (Entity): R16	supports Arg1:T30 Arg2:T29
# Skipping line due to unexpected argument count (Relation): T32	background_claim 7848 7988	precompute principal components of the deformation influences for individual kinematic joints instead of storing displacements for key poses
# Skipping line due to unexpected argument count (Relation): T33	background_claim 7998 8078	enabling realtime rendering large nonlinear finite element models of human hands
# Skipping line due to unexpected argument count (Relation): T34	data 7842 7847	[ 3 ]
# Skipping line due to unexpected format (Entity): R17	supports Arg1:T34 Arg2:T32
# Skipping line due to unexpected format (Entity): R18	supports Arg1:T32 Arg2:T33
# Skipping line due to unexpected format (Entity): R19	supports Arg1:T33 Arg2:T29
# Skipping line due to unexpected argument count (Relation): T35	background_claim 8086 8172	introduce weighted pose space deformation for deforming realistic models of human hand
# Skipping line due to unexpected argument count (Relation): T36	data 8080 8085	[ 4 ]
# Skipping line due to unexpected format (Entity): R20	supports Arg1:T36 Arg2:T35
# Skipping line due to unexpected format (Entity): R21	supports Arg1:T35 Arg2:T29
# Skipping line due to unexpected argument count (Relation): T37	background_claim 8356 8447	these example-based approaches can be considered as non-parametric skin deformation methods
# Skipping line due to unexpected argument count (Relation): T38	background_claim 8196 8297	identifies statistically relevant bones and approximates bone transforms from example mesh animations
# Skipping line due to unexpected argument count (Relation): T39	data 8190 8195	[ 5 ]
# Skipping line due to unexpected format (Entity): R22	supports Arg1:T39 Arg2:T38
# Skipping line due to unexpected format (Entity): R23	supports Arg1:T38 Arg2:T29
# Skipping line due to unexpected argument count (Relation): T40	background_claim 8684 8737	these have also seen some development in recent years
# Skipping line due to unexpected argument count (Relation): T41	data 8738 8743	[ 6 ]
# Skipping line due to unexpected argument count (Relation): T42	data 8745 8750	[ 7 ]
# Skipping line due to unexpected format (Entity): R24	supports Arg1:T41 Arg2:T40
# Skipping line due to unexpected format (Entity): R25	supports Arg1:T42 Arg2:T40
# Skipping line due to unexpected argument count (Relation): T43	background_claim 8870 8927	are also common practices in the entertainment production
# Skipping line due to unexpected argument count (Relation): T44	background_claim 8752 8785	Skinning using free form lattices
# Skipping invalid argument (Relation): NURBS
# Skipping invalid argument (Relation): curves
# Skipping line due to unexpected format (Entity): R26	parts_of_same Arg1:T44 Arg2:T45
# Skipping line due to unexpected format (Entity): R27	parts_of_same Arg1:T43 Arg2:T45
# Skipping line due to unexpected argument count (Relation): T46	data 8815 8821	[ 10 ]
# Skipping line due to unexpected argument count (Relation): T47	data 8786 8791	[ 8 ]
# Skipping line due to unexpected argument count (Relation): T48	data 8793 8798	[ 9 ]
# Skipping line due to unexpected format (Entity): R28	supports Arg1:T47 Arg2:T44
# Skipping line due to unexpected format (Entity): R29	supports Arg1:T48 Arg2:T44
# Skipping line due to unexpected format (Entity): R30	supports Arg1:T46 Arg2:T45
# Skipping line due to unexpected argument count (Relation): T49	own_claim 9263 9308	the inverse operation can improve the results
# Skipping line due to unexpected argument count (Relation): T50	own_claim 9590 9619	inverse operation is required
# Skipping line due to unexpected format (Entity): R31	semantically_same Arg1:T49 Arg2:T21
# Skipping line due to unexpected argument count (Relation): T51	background_claim 10442 10525	SSD is widely applied to interactive applications such as games and virtual reality
# Skipping line due to unexpected argument count (Relation): T52	background_claim 10531 10586	it is implemented in most commercial animation packages
# Skipping invalid argument (Relation): its
# Skipping invalid argument (Relation): simplicity
# Skipping line due to unexpected argument count (Relation): T54	data 10430 10440	efficiency
# Skipping line due to unexpected format (Entity): R32	supports Arg1:T54 Arg2:T51
# Skipping line due to unexpected format (Entity): R33	supports Arg1:T53 Arg2:T51
# Skipping line due to unexpected format (Entity): R34	supports Arg1:T54 Arg2:T52
# Skipping line due to unexpected format (Entity): R35	supports Arg1:T53 Arg2:T52
# Skipping line due to unexpected argument count (Relation): T55	background_claim 12084 12179	SSD is very popular in circumstances that require animating a number of characters in real time
# Skipping line due to unexpected argument count (Relation): T56	data 12014 12082	vertex transformations can be easily implemented in the graphic card
# Skipping line due to unexpected format (Entity): R36	supports Arg1:T56 Arg2:T55
# Skipping line due to unexpected argument count (Relation): T57	background_claim 12335 12494	the domain of adjusting one vertex in this way is strictly limited to the linear subspace formed by the vertex as transformed by joints influencing this vertex
# Skipping line due to unexpected argument count (Relation): T58	background_claim 12243 12329	When a character goes wrong in some pose, animators can adjust joint influence weights
# Skipping line due to unexpected format (Entity): R37	contradicts Arg1:T57 Arg2:T58
# Skipping line due to unexpected argument count (Relation): T59	background_claim 12741 12832	SSD cannot synthesize many parts of a character skin involving complicated joint structures
# Skipping line due to unexpected argument count (Relation): T60	background_claim 12671 12712	deforming is limited to a linear subspace
# Skipping line due to unexpected argument count (Relation): T61	data 12634 12639	[ 1 ]
# Skipping line due to unexpected format (Entity): R38	supports Arg1:T61 Arg2:T60
# Skipping line due to unexpected format (Entity): R39	supports Arg1:T60 Arg2:T59
# Skipping line due to unexpected argument count (Relation): T62	background_claim 12917 13008	a combination of SSD and shape blending providing nice solution to above mentioned problems
# Skipping line due to unexpected argument count (Relation): T63	data 12908 12913	[ 1 ]
# Skipping line due to unexpected format (Entity): R40	supports Arg1:T63 Arg2:T62
# Skipping line due to unexpected argument count (Relation): T64	background_claim 14983 15062	PSD and improved example-based schemes have been discussed in many publications
# Skipping line due to unexpected argument count (Relation): T65	data 15064 15069	[ 2 ]
# Skipping line due to unexpected argument count (Relation): T66	data 15071 15076	[ 3 ]
# Skipping line due to unexpected argument count (Relation): T67	data 15078 15083	[ 4 ]
# Skipping line due to unexpected argument count (Relation): T68	own_claim 15086 15151	the reason why the inverse should be performed is still ambiguous
# Skipping line due to unexpected format (Entity): R41	supports Arg1:T65 Arg2:T64
# Skipping line due to unexpected format (Entity): R42	supports Arg1:T66 Arg2:T64
# Skipping line due to unexpected format (Entity): R43	supports Arg1:T67 Arg2:T64
# Skipping line due to unexpected format (Entity): R44	contradicts Arg1:T64 Arg2:T68
# Skipping line due to unexpected argument count (Relation): T69	own_claim 15220 15338	inverting the SSD (and other deformations) in order to interpolate the examples in the rest pose is a the right choice
# Skipping line due to unexpected format (Entity): R45	semantically_same Arg1:T69 Arg2:T50
# Skipping line due to unexpected argument count (Relation): T70	own_claim 15478 15498	it is an improvement
# Skipping line due to unexpected format (Entity): R46	semantically_same Arg1:T70 Arg2:T69
# Skipping line due to unexpected argument count (Relation): T71	own_claim 15754 15791	the superiority of the inverse method
# Skipping line due to unexpected format (Entity): R47	semantically_same Arg1:T71 Arg2:T70
# Skipping line due to unexpected format (Entity): R48	semantically_same Arg1:T50 Arg2:T49
# Skipping line due to unexpected argument count (Relation): T72	own_claim 16991 17058	SSD −1 simply is the inverse transformation matrix generated by SSD
# Skipping line due to unexpected argument count (Relation): T73	data 16963 16989	SSD is a 3D transformation
# Skipping line due to unexpected format (Entity): R49	supports Arg1:T73 Arg2:T72
# Skipping line due to unexpected argument count (Relation): T74	own_claim 17950 17980	the inverse method is superior
# Skipping line due to unexpected format (Entity): R50	semantically_same Arg1:T74 Arg2:T71
# Skipping line due to unexpected argument count (Relation): T75	background_claim 19098 19196	Taking the model in rest pose as an example is a common practice when applying shape interpolation
# Skipping line due to unexpected argument count (Relation): T76	background_claim 19204 19295	interpolating effects from other examples should not change the original model in rest pose
# Skipping line due to unexpected format (Entity): R51	supports Arg1:T76 Arg2:T75
# Skipping line due to unexpected argument count (Relation): T77	own_claim 19334 19603	we have: ω 1x = φ 11 −1 d 1x + φ 12 −1 d 2x = φ 12 −1 d 2x ω 2x = φ 21 −1 d 1x + φ 22 −1 d 2x = φ 22 −1 d 2x = d 2x ω 1y = φ 11 −1 d 1y + φ 12 −1 d 2y = φ 12 −1 d 2y ω 2y = φ 21 −1 d 1y + φ 22 −1 d 2y = φ 22 −1 d 2y = d 2y where φ i −1 j is the (i, j)th element of Φ −1
# Skipping line due to unexpected format (Entity): R52	supports Arg1:T75 Arg2:T77
# Skipping line due to unexpected argument count (Relation): T78	own_claim 20353 20469	we simplify SSD as a rotation transformation ignoring other issues such as accumulating effects from the first joint
# Skipping line due to unexpected argument count (Relation): T79	own_claim 20318 20351	only the second joint is rotating
# Skipping line due to unexpected format (Entity): R53	supports Arg1:T79 Arg2:T78
# Skipping line due to unexpected argument count (Relation): T80	own_claim 21667 21764	in forward case, the direction of deformed vertex always keeps the same with the example cylinder
# Skipping line due to unexpected argument count (Relation): T81	data 21765 21777	( figure 4 )
# Skipping line due to unexpected format (Entity): R54	supports Arg1:T81 Arg2:T80
# Skipping line due to unexpected argument count (Relation): T82	own_claim 21779 21866	For inverse PSD however, that direction is changed along with the rotation of the joint
# Skipping line due to unexpected format (Entity): R55	supports Arg1:T81 Arg2:T82
# Skipping line due to unexpected argument count (Relation): T83	own_claim 22106 22158	PSD is supposed to be a method as “local” correction
# Skipping line due to unexpected argument count (Relation): T84	own_claim 22172 22269	pose space should not be extended to a whole space that has to incorporate all influenced objects
# Skipping line due to unexpected format (Entity): R56	supports Arg1:T83 Arg2:T84
# Skipping line due to unexpected argument count (Relation): T85	data 22082 22104	a matter of experience
# Skipping line due to unexpected format (Entity): R57	supports Arg1:T85 Arg2:T83
# Skipping line due to unexpected argument count (Relation): T86	own_claim 22282 22353	large amount of unnecessary works of building examples will be required
# Skipping line due to unexpected argument count (Relation): T87	own_claim 22359 22415	the distance between different poses is also meaningless
# Skipping line due to unexpected format (Entity): R58	supports Arg1:T86 Arg2:T84
# Skipping line due to unexpected format (Entity): R59	supports Arg1:T87 Arg2:T84
# Skipping line due to unexpected argument count (Relation): T88	background_claim 23066 23128	most of which have been implemented in most animation packages
# Skipping line due to unexpected argument count (Relation): T89	background_claim 22985 23049	in many circumstances, other deformation schemes will be adopted
# Skipping line due to unexpected argument count (Relation): T90	data 23058 23064	[ 10 ]
# Skipping line due to unexpected argument count (Relation): T91	data 23051 23056	[ 9 ]
# Skipping line due to unexpected format (Entity): R60	supports Arg1:T90 Arg2:T89
# Skipping line due to unexpected format (Entity): R61	supports Arg1:T91 Arg2:T89
# Skipping line due to unexpected argument count (Relation): T92	own_claim 23289 23371	we can deform the original character model from rest pose to another specific pose
# Skipping line due to unexpected argument count (Relation): T93	background_claim 25039 25152	One advantage of Powell’s classic method is that it does not need explicit computation of the function’s gradient
# Skipping line due to unexpected argument count (Relation): T94	data 25154 25160	[ 12 ]
# Skipping line due to unexpected format (Entity): R62	supports Arg1:T94 Arg2:T93
# Skipping line due to unexpected argument count (Relation): T95	own_claim 25264 25291	Powell’s method is suitable
# Skipping line due to unexpected argument count (Relation): T96	data 25170 25259	we are treating the skinning operations as a “black box”, their gradient is not available
# Skipping line due to unexpected format (Entity): R63	supports Arg1:T96 Arg2:T95
# Skipping line due to unexpected argument count (Relation): T97	background_claim 25659 25789	after repeated cycles of M line minimizations on conjugate directions, the optimization will in due course converge to the minimum
# Skipping line due to unexpected argument count (Relation): T98	data 25790 25796	[ 12 ]
# Skipping line due to unexpected format (Entity): R64	supports Arg1:T98 Arg2:T97
# Skipping line due to unexpected argument count (Relation): T99	own_claim 26918 27029	If the SSD transformation in equation 1 is singular, some types of inverse PSD deformation will not be possible
# Skipping line due to unexpected argument count (Relation): T100	data 27039 27141	any component of the desired deformation that lies in the null space of the SSD matrix will be ignored
# Skipping line due to unexpected format (Entity): R65	supports Arg1:T100 Arg2:T99
# Skipping line due to unexpected argument count (Relation): T101	own_claim 27152 27175	singular cases are rare
# Skipping line due to unexpected argument count (Relation): T102	own_claim 27324 27415	it is possible to handle these cases with a small rearrangement of the inverse PSD approach
# Skipping line due to unexpected argument count (Relation): T103	data 27177 27321	one example is a joint with 180 o rotation and equal 2 1 , 2 1 weights on the two joint frames, which is an unrealistic case of selfintersection
# Skipping line due to unexpected format (Entity): R66	supports Arg1:T103 Arg2:T101
# Skipping line due to unexpected format (Entity): R67	contradicts Arg1:T99 Arg2:T102
# Skipping line due to unexpected argument count (Relation): T104	own_claim 27847 27875	it will be generally be zero
# Skipping line due to unexpected argument count (Relation): T105	data 27823 27845	w i is being minimized
# Skipping line due to unexpected format (Entity): R68	supports Arg1:T105 Arg2:T104
# Skipping line due to unexpected argument count (Relation): T106	own_claim 27881 27992	will be non-zero only if it is not possible to obtain the desired deformation v i using SKINNING i (v r + d i )
# Skipping line due to unexpected format (Entity): R69	supports Arg1:T105 Arg2:T106
# Skipping line due to unexpected argument count (Relation): T107	own_claim 28651 28742	Inverse skinning integrates SSD and shape interpolation more firmly than its forward rival.
# Skipping line due to unexpected argument count (Relation): T108	own_claim 28960 29042	the inverse approach presents better performance and more consistent interpolation
# Skipping line due to unexpected argument count (Relation): T109	data 29045 29066	Figure 7 to Figure 10
# Skipping line due to unexpected format (Entity): R70	supports Arg1:T109 Arg2:T108
# Skipping line due to unexpected argument count (Relation): T110	own_claim 28758 28948	the direction of deformed vertex in inverse skinning is linearly proportional to joint rotations in a simplified example, while the forward PSD does not incorporate the direction information
# Skipping line due to unexpected format (Entity): R71	supports Arg1:T110 Arg2:T108
# Skipping line due to unexpected format (Entity): R72	semantically_same Arg1:T108 Arg2:T74
# Skipping line due to unexpected argument count (Relation): T111	own_claim 29268 29315	the minimizing process will introduce more cost
# Skipping line due to unexpected argument count (Relation): T112	own_claim 29640 29689	The cost of the inverse operation is not critical
# Skipping line due to unexpected argument count (Relation): T113	own_claim 29706 29735	it is a one time “setup” cost
# Skipping line due to unexpected argument count (Relation): T114	own_claim 29741 29845	the compute time is insignificant compared to the human time required to sculpt the desired deformations
# Skipping line due to unexpected format (Entity): R73	supports Arg1:T113 Arg2:T112
# Skipping line due to unexpected format (Entity): R74	supports Arg1:T114 Arg2:T112
# Skipping line due to unexpected argument count (Relation): T115	data 2835 2853	a frame goes wrong
# Skipping line due to unexpected format (Entity): R75	supports Arg1:T115 Arg2:T4
# Skipping line due to unexpected format (Entity): R76	semantically_same Arg1:T14 Arg2:T15
# Skipping invalid argument (Relation): physical
# Skipping invalid argument (Relation): principles
# Skipping line due to unexpected format (Entity): R77	supports Arg1:T116 Arg2:T25
# Skipping line due to unexpected argument count (Relation): T117	data 2727 2753	the model is very detailed
# Skipping line due to unexpected argument count (Relation): T118	data 2758 2818	playback of animation becomes quite heavy and time consuming
# Skipping line due to unexpected format (Entity): R78	supports Arg1:T117 Arg2:T3
# Skipping line due to unexpected format (Entity): R79	supports Arg1:T118 Arg2:T3
# Skipping line due to unexpected format (Entity): R80	supports Arg1:T9 Arg2:T6
# Skipping line due to unexpected argument count (Relation): T119	background_claim 3993 4044	For those applications that require visual fidelity
# Skipping line due to unexpected argument count (Relation): T120	background_claim 4062 4098	SSD serves only as a basic framework
# Skipping line due to unexpected format (Entity): R81	parts_of_same Arg1:T119 Arg2:T120
# Skipping line due to unexpected argument count (Relation): T121	background_claim 4439 4535	PSD smoothly interpolates these meshes in pose space and produces visually attractive animations
# Skipping line due to unexpected argument count (Relation): T122	background_claim 4951 4989	Besides SSD, other skinning approaches
# Skipping line due to unexpected argument count (Relation): T123	background_claim 5041 5060	can also be applied
# Skipping invalid argument (Relation): rigid
# Skipping invalid argument (Relation): skinning
# Skipping line due to unexpected argument count (Relation): T125	data 5014 5035	Free Form Deformation
# Skipping line due to unexpected format (Entity): R82	parts_of_same Arg1:T122 Arg2:T123
# Skipping line due to unexpected format (Entity): R83	supports Arg1:T124 Arg2:T122
# Skipping line due to unexpected format (Entity): R84	supports Arg1:T125 Arg2:T122
# Skipping line due to unexpected argument count (Relation): T126	background_claim 6265 6356	physical modelling and animation is another field providing realistic character simulations
# Skipping line due to unexpected argument count (Relation): T127	background_claim 8578 8682	Simpler parametric skinning approaches (of which SSD is the prototype) have a fixed number of parameters
# Skipping line due to unexpected format (Entity): R85	supports Arg1:T41 Arg2:T127
# Skipping line due to unexpected format (Entity): R86	supports Arg1:T42 Arg2:T127
# Skipping line due to unexpected argument count (Relation): T128	own_claim 9346 9441	the direction of deformed vertices from inverse skinning is a linear function of joint rotation
# Skipping line due to unexpected argument count (Relation): T129	own_claim 9449 9510	in the forward approach, that direction is kept as a constant
# Skipping line due to unexpected format (Entity): R87	contradicts Arg1:T129 Arg2:T128
# Skipping line due to unexpected argument count (Relation): T130	own_claim 9695 9848	propose a unified framework which can be implemented on high-end commercial packages while allowing any proprietary skinning operators to be incorporated
# Skipping line due to unexpected argument count (Relation): T131	background_claim 10115 10276	Skeleton Subspace Deformation (SSD) is a basic algorithm that is used to define how the character surface deforms following movements of its underlying skeletons
# Skipping line due to unexpected argument count (Relation): T132	data 10309 10315	[ 11 ]
# Skipping line due to unexpected format (Entity): R88	supports Arg1:T132 Arg2:T131
# Skipping line due to unexpected argument count (Relation): T133	data 10949 10987	SSD is adopted to define this relation
# Skipping line due to unexpected argument count (Relation): T134	background_claim 10989 11158	each vertex or control point of the character surface is provided with a list of joints, that will influence it, along with the weight indicating the amount of influence
# Skipping line due to unexpected format (Entity): R89	supports Arg1:T133 Arg2:T134
# Skipping line due to unexpected argument count (Relation): T135	background_claim 11192 11326	the position of a vertex in the animated pose is the result of weighted linear blending of its transformation by each associated joint
# Skipping line due to unexpected argument count (Relation): T136	data 11165 11190	the character is animated
# Skipping line due to unexpected format (Entity): R90	supports Arg1:T136 Arg2:T135
# Skipping line due to unexpected argument count (Relation): T137	background_claim 12572 12615	The famous SSD problem of “collapsed elbow”
# Skipping line due to unexpected format (Entity): R91	supports Arg1:T60 Arg2:T137
# Skipping line due to unexpected argument count (Relation): T138	data 13915 13942	sculpted in N example poses
# Skipping line due to unexpected argument count (Relation): T139	data 13900 13910	a vertex v
# Skipping line due to unexpected format (Entity): R92	parts_of_same Arg1:T139 Arg2:T138
# Skipping line due to unexpected argument count (Relation): T140	own_claim 13949 14047	there are N delta d i , i = 0, . . . , N − 1 corresponding to each pose x i , i = 0, . . . , N − 1
# Skipping line due to unexpected format (Entity): R93	supports Arg1:T138 Arg2:T140
# Skipping line due to unexpected argument count (Relation): T141	own_claim 15515 15545	SSD as the underlying skinning
# Skipping line due to unexpected argument count (Relation): T142	own_claim 15553 15632	an explicit form of basic skinning can help to simplify our task of explanation
# Skipping line due to unexpected format (Entity): R94	supports Arg1:T142 Arg2:T141
# Skipping line due to unexpected argument count (Relation): T143	data 19004 19059	in the rest pose, we didn’t generate any movement for v
# Skipping line due to unexpected argument count (Relation): T144	own_claim 19067 19096	d 1 = [d 1x , d 1y ] = [0, 0]
# Skipping line due to unexpected format (Entity): R95	supports Arg1:T143 Arg2:T144
# Skipping line due to unexpected argument count (Relation): T145	data 19308 19333	by solving above equation
# Skipping line due to unexpected format (Entity): R96	supports Arg1:T145 Arg2:T77
# Skipping line due to unexpected argument count (Relation): T146	data 19613 19618	i = j
# Skipping line due to unexpected argument count (Relation): T147	own_claim 19620 19632	φ i −1 j = 1
# Skipping line due to unexpected format (Entity): R97	supports Arg1:T146 Arg2:T147
# Skipping line due to unexpected argument count (Relation): T148	own_claim 20030 20137	this angle α p is a constant and depends only on the value of delta in the second pose d 2 = [d 2x , d 2y ]
# Skipping line due to unexpected argument count (Relation): T149	own_claim 19817 20018	tan α p = d d x y = ω ω 1x 1y φ φ (x (x − − x x 1 1 ) ) + + ω ω 2y 2x φ φ (x (x − − x x 2 2 ) ) = φ φ 12 12 −1 −1 d d 2x 2y φ φ (x (x − − x x 1 1 ) ) + + d d 2x 2y φ φ (x (x − − x x 2 2 ) ) = d 2y d 2x
# Skipping line due to unexpected format (Entity): R98	supports Arg1:T149 Arg2:T148
# Skipping line due to unexpected argument count (Relation): T150	own_claim 19683 19700	tan α p = d d x y
# Skipping line due to unexpected format (Entity): R99	supports Arg1:T150 Arg2:T149
# Skipping line due to unexpected argument count (Relation): T151	own_claim 21868 21920	The case described above is quite common in practice
# Skipping line due to unexpected argument count (Relation): T152	data 21926 21973	animating shoulder, elbow, knee, hip-bone, neck
# Skipping line due to unexpected format (Entity): R100	supports Arg1:T152 Arg2:T151
# Skipping line due to unexpected argument count (Relation): T153	own_claim 21980 22058	All these parts would rotate from the rest pose with some angle to other poses
# Skipping line due to unexpected argument count (Relation): T154	own_claim 23151 23225	a unified framework in which no explicit inverse operation is necessitated
# Skipping line due to unexpected format (Entity): R101	supports Arg1:T88 Arg2:T154
# Skipping line due to unexpected argument count (Relation): T155	data 23233 23288	a basic skinning method supported by animation packages
# Skipping line due to unexpected format (Entity): R102	supports Arg1:T155 Arg2:T92
# Skipping line due to unexpected argument count (Relation): T156	own_claim 23494 23537	v i t = v i + d i = SKINNING i (v r ) + d i
# Skipping line due to unexpected argument count (Relation): T157	own_claim 23399 23492	we need to replace SSD with SKINNING in the inverse skinning algorithm as such for equation 4
# Skipping line due to unexpected argument count (Relation): T158	data 23376 23397	the more general case
# Skipping line due to unexpected format (Entity): R103	supports Arg1:T158 Arg2:T157
# Skipping line due to unexpected format (Entity): R104	supports Arg1:T157 Arg2:T156
# Skipping line due to unexpected argument count (Relation): T159	own_claim 23613 23765	To find delta d i in the rest pose: v i = SKINNING i (v r ) + d i = SKINNING i (v r + d i ) we can setup a minimization problem to minimize the function
# Skipping line due to unexpected argument count (Relation): T160	own_claim 24028 24110	This function can be given to Powell’s method to find d i at the minimum of f (d )
# Skipping line due to unexpected argument count (Relation): T161	data 24112 24153	For each example pose P i , we have a d i
# Skipping line due to unexpected argument count (Relation): T162	own_claim 24161 24270	we can apply radial basis function to d i (i = 0 . . . n − 1) in pose space to obtain ω i (i = 0 . . . n − 1)
# Skipping line due to unexpected format (Entity): R105	supports Arg1:T161 Arg2:T162
# Skipping line due to unexpected argument count (Relation): T163	own_claim 25293 25398	Minimizing the function f (d ) in a particular direction is actually minimization problem of one variable
# Skipping line due to unexpected argument count (Relation): T164	background_claim 25440 25556	Powell’s idea is trying to find each minimum of function f (d ) in different direction until f (d ) stops decreasing
# Skipping line due to unexpected argument count (Relation): T165	background_claim 25558 25629	How to choose the next direction is the main concern of Powell’s method
# Skipping line due to unexpected argument count (Relation): T166	background_claim 26052 26159	In Maya, “tweaking” is a procedure adding delta values to original surface vertices before any deformations
# Skipping line due to unexpected argument count (Relation): T167	background_claim 26161 26251	It is actu- ally Maya’s form of rest-pose editing for their built-in deformation operators
# Skipping line due to unexpected argument count (Relation): T168	own_claim 26280 26323	the whole system is divided into two phases
# Skipping invalid argument (Relation): Figure
# Skipping invalid argument (Relation): 6
# Skipping line due to unexpected format (Entity): R106	supports Arg1:T169 Arg2:T168
# Skipping line due to unexpected argument count (Relation): T170	own_claim 26325 26414	The first phase is to find each delta in the rest pose corresponding to each example pose
# Skipping line due to unexpected format (Entity): R107	supports Arg1:T170 Arg2:T168
# Skipping line due to unexpected argument count (Relation): T171	own_claim 26570 26665	the second phase that is a linear system performing RBF interpolation to obtain the PSD weights
# Skipping line due to unexpected format (Entity): R108	supports Arg1:T171 Arg2:T168
# Skipping line due to unexpected argument count (Relation): T172	own_claim 27753 27791	only minimal code changed are required
# Skipping line due to unexpected argument count (Relation): T173	own_claim 27596 27745	The final synthesis is then v x = SKINNING(v r + d x ) + w x where w x is interpolated after SKINNING by applying the same RBF scheme as used for d x
# Skipping line due to unexpected format (Entity): R109	supports Arg1:T173 Arg2:T172
# Skipping line due to unexpected argument count (Relation): T174	data 28012 28045	the SSD transform is nearsingular
# Skipping line due to unexpected argument count (Relation): T175	own_claim 28047 28143	the solved d i can be much large than other d k , which can result in poorly posed interpolation
# Skipping line due to unexpected format (Entity): R110	supports Arg1:T174 Arg2:T175
# Skipping line due to unexpected argument count (Relation): T176	own_claim 29881 29918	the synthesis is potentially realtime
# Skipping line due to unexpected argument count (Relation): T177	own_claim 29925 29971	no extra computing is involved in this process
# Skipping line due to unexpected format (Entity): R111	supports Arg1:T177 Arg2:T176
# Skipping line due to unexpected argument count (Relation): T178	data 29852 29879	the linear system is solved
# Skipping line due to unexpected format (Entity): R112	supports Arg1:T178 Arg2:T176
# Skipping line due to unexpected argument count (Relation): T179	data 5433 5493	only one joint rotation and two example poses are considered
# Skipping line due to unexpected format (Entity): R113	supports Arg1:T179 Arg2:T20
# Skipping line due to unexpected argument count (Relation): T180	background_claim 3309 3338	A nice review of SSD is given
# Skipping line due to unexpected argument count (Relation): T181	data 3344 3345	1
# Skipping line due to unexpected format (Entity): R114	supports Arg1:T181 Arg2:T180
# Skipping invalid argument (Relation): resculpting
# Skipping invalid argument (Relation): models
# Skipping line due to unexpected format (Entity): R115	supports Arg1:T182 Arg2:T4
# Skipping invalid argument (Relation): re-rigging
# Skipping invalid argument (Relation): skeletons
# Skipping line due to unexpected format (Entity): R116	supports Arg1:T183 Arg2:T4

# %%
annotation
# Out:
# [{'id': 'T24', 'relation_type': 'data 6583 6605', 'arguments': {}},
#  {'id': 'T45', 'relation_type': 'background_claim 8802 8814', 'arguments': {}},
#  {'id': 'T53', 'relation_type': 'data 10411 10425', 'arguments': {}},
#  {'id': 'T116', 'relation_type': 'data 6364 6383', 'arguments': {}},
#  {'id': 'T124', 'relation_type': 'data 4998 5012', 'arguments': {}},
#  {'id': 'T169', 'relation_type': 'data 26269 26277', 'arguments': {}},
#  {'id': 'T182', 'relation_type': 'data 2906 2924', 'arguments': {}},
#  {'id': 'T183', 'relation_type': 'data 2928 2948', 'arguments': {}}]

# %%
def read_ann_file(ann_file_path):
    annotations = []
    
    with open(ann_file_path, 'r', encoding='utf-8') as file:
        for line in file:
            line = line.strip()
            if not line:  # Skip empty lines
                continue
            try:
                parts = line.split('\t')
                
                if len(parts) == 2:
                    # Entity annotation (e.g., T1 Person 0 4 John)
                    annotation_id, annotation_details = parts
                    entity_details = annotation_details.split()
                    if len(entity_details) == 4:
                        entity_type, start, end, text = entity_details
                        annotations.append({
                            "id": annotation_id,
                            "type": entity_type,
                            "start": int(start),
                            "end": int(end),
                            "text": text
                        })
                    else:
                        print(f"Skipping malformed entity: {line}")
                
                elif len(parts) == 3:
                    # Relation annotation (e.g., R1 Located_in Arg1:T1 Arg2:T2)
                    annotation_id, relation_type, args = parts
                    arguments = args.split()
                    annotations.append({
                        "id": annotation_id,
                        "relation_type": relation_type,
                        "arguments": arguments
                    })
                
                else:
                    print(f"Skipping malformed line: {line}")
            except Exception as e:
                print(f"Error processing line: {line}\n{str(e)}")
    
    return annotations

# %%
import nltk

def read_ann_file(ann_file_path):
    annotations = []
    
    with open(ann_file_path, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split('\t')
            if len(parts) == 2:
                # Entity annotation (e.g., T1 Person 0 4 John)
                annotation_id, annotation_details = parts
                entity_type, start, end, text = annotation_details.split()
                annotations.append({
                    "id": annotation_id,
                    "type": entity_type,
                    "start": int(start),
                    "end": int(end),
                    "text": text
                })
            elif len(parts) == 3:
                # Relation annotation (e.g., R1 Located_in Arg1:T1 Arg2:T2)
                annotation_id, relation_type, args = parts
                arguments = args.split()
                annotations.append({
                    "id": annotation_id,
                    "relation_type": relation_type,
                    "arguments": arguments
                })
    
    return annotations

# %%
file="A01.ann"
annotation=read_ann_file(file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 file="A01.ann"
# ----> 2 annotation=read_ann_file(file)
#
# Cell In[14], line 12, in read_ann_file(ann_file_path)
#       9 if len(parts) == 2:
#      10     # Entity annotation (e.g., T1 Person 0 4 John)
#      11     annotation_id, annotation_details = parts
# ---> 12     entity_type, start, end, text = annotation_details.split()
#      13     annotations.append({
#      14         "id": annotation_id,
#      15         "type": entity_type,
#    (...)
#      18         "text": text
#      19     })
#      20 elif len(parts) == 3:
#      21     # Relation annotation (e.g., R1 Located_in Arg1:T1 Arg2:T2)
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %%
annotation
# Out:
# [{'id': 'T1',
#   'relation_type': 'background_claim 2417 2522',
#   'arguments': ['complicated',
#    '3D',
#    'character',
#    'models',
#    'are',
#    'widely',
#    'used',
#    'in',
#    'fields',
#    'of',
#    'entertainment,',
#    'virtual',
#    'reality,',
#    'medicine',
#    'etc']},
#  {'id': 'T2',
#   'relation_type': 'background_claim 2524 2640',
#   'arguments': ['The',
#    'range',
#    'of',
#    'breathtaking',
#    'realistic',
#    '3D',
#    'models',
#    'is',
#    'only',
#    'limited',
#    'by',
#    'the',
#    'creativity',
#    'of',
#    'artists',
#    'and',
#    'resolution',
#    'of',
#    'devices']},
#  {'id': 'T4',
#   'relation_type': 'background_claim 2855 2897',
#   'arguments': ['a', 'production', 'cannot', 'afford', 'major', 'revisions']},
#  {'id': 'T5',
#   'relation_type': 'own_claim 2961 3041',
#   'arguments': ['providing',
#    'a',
#    'flexible',
#    'and',
#    'efficient',
#    'solution',
#    'to',
#    'animation',
#    'remains',
#    'an',
#    'open',
#    'problem']},
#  {'id': 'T6',
#   'relation_type': 'background_claim 3211 3307',
#   'arguments': ['Skeleton',
#    'Subspace',
#    'Deformation',
#    '(SSD)',
#    'is',
#    'the',
#    'predominant',
#    'approach',
#    'to',
#    'character',
#    'skinning',
#    'at',
#    'present']},
#  {'id': 'T3',
#   'relation_type': 'background_claim 2642 2709',
#   'arguments': ['Driving',
#    '3D',
#    'models',
#    'in',
#    'a',
#    'natural',
#    'and',
#    'believable',
#    'manner',
#    'is',
#    'not',
#    'trivial']},
#  {'id': 'T7',
#   'relation_type': 'data 3433 3459',
#   'arguments': ['its', 'ease', 'of', 'implementation']},
#  {'id': 'T8',
#   'relation_type': 'data 3464 3485',
#   'arguments': ['low', 'cost', 'of', 'computing']},
#  {'id': 'T9',
#   'relation_type': 'background_claim 3349 3425',
#   'arguments': ['SSD',
#    'is',
#    'widely',
#    'used',
#    'in',
#    'games,',
#    'virtual',
#    'reality',
#    'and',
#    'other',
#    'realtime',
#    'applications']},
#  {'id': 'T10',
#   'relation_type': 'background_claim 3702 3787',
#   'arguments': ['artists',
#    'will',
#    'edit',
#    'the',
#    'geometry',
#    'of',
#    'characters',
#    'in',
#    'the',
#    'rest',
#    'pose',
#    'to',
#    'fine-tune',
#    'animations']},
#  {'id': 'T11',
#   'relation_type': 'background_claim 3789 3826',
#   'arguments': ['This', 'approach', 'is', 'not', 'commonly', 'applied']},
#  {'id': 'T12',
#   'relation_type': 'background_claim 3843 3899',
#   'arguments': ['editing',
#    'in',
#    'the',
#    'rest',
#    'pose',
#    'will',
#    'influence',
#    'most',
#    'other',
#    'poses']},
#  {'id': 'T13',
#   'relation_type': 'background_claim 3919 3991',
#   'arguments': ['SSD',
#    'is',
#    'also',
#    'notorious',
#    'for',
#    'artifacts',
#    'at',
#    'rotating',
#    'elbows',
#    'and',
#    'extreme',
#    'poses']},
#  {'id': 'T14',
#   'relation_type': 'background_claim 4186 4299',
#   'arguments': ['Example',
#    'based',
#    'skinning',
#    'methods',
#    'such',
#    'as',
#    'Pose',
#    'Space',
#    'Deformation',
#    '(PSD)',
#    'are',
#    'candidates',
#    'for',
#    'correcting',
#    'SSD',
#    'limitations']},
#  {'id': 'T15',
#   'relation_type': 'background_claim 4555 4610',
#   'arguments': ['PSD',
#    'may',
#    'be',
#    'used',
#    'as',
#    'a',
#    'compensation',
#    'to',
#    'the',
#    'underlying',
#    'SSD']},
#  {'id': 'T16',
#   'relation_type': 'background_claim 4616 4688',
#   'arguments': ['the',
#    'animator',
#    'specifies',
#    'the',
#    'PSD',
#    'examples',
#    'after',
#    'the',
#    'SSD',
#    'has',
#    'been',
#    'performed']},
#  {'id': 'T17',
#   'relation_type': 'background_claim 4720 4804',
#   'arguments': ['the',
#    'examples',
#    'are',
#    'best',
#    'interpolated',
#    'in',
#    'the',
#    'rest',
#    'pose,',
#    'before',
#    'the',
#    'SSD',
#    'has',
#    'been',
#    'applied']},
#  {'id': 'T18',
#   'relation_type': 'background_claim 4816 4949',
#   'arguments': ['the',
#    'action',
#    'of',
#    'the',
#    'SSD',
#    'and',
#    'any',
#    'other',
#    'deformations',
#    'must',
#    'be',
#    '“inverted”',
#    'in',
#    'order',
#    'to',
#    'push',
#    'the',
#    'example',
#    'compensation',
#    'before',
#    'these',
#    'operations']},
#  {'id': 'T19',
#   'relation_type': 'background_claim 5264 5326',
#   'arguments': ['SSD',
#    'is',
#    'the',
#    'most',
#    'representative',
#    'in',
#    'the',
#    'family',
#    'of',
#    'basic',
#    'skinning']},
#  {'id': 'T20',
#   'relation_type': 'own_claim 5510 5591',
#   'arguments': ['this',
#    'inverse',
#    'strategy',
#    'has',
#    'a',
#    'better',
#    'performance',
#    'than',
#    'the',
#    'same',
#    'framework',
#    'without',
#    'it']},
#  {'id': 'T21',
#   'relation_type': 'own_claim 5866 5919',
#   'arguments': ['this',
#    'approach',
#    'will',
#    'improve',
#    'the',
#    'quality',
#    'of',
#    'deformation']},
#  {'id': 'T22',
#   'relation_type': 'background_claim 6489 6540',
#   'arguments': ['they',
#    'are',
#    'seldom',
#    'applied',
#    'to',
#    'interactive',
#    'applications']},
#  {'id': 'T23',
#   'relation_type': 'data 6552 6578',
#   'arguments': ['the', 'high', 'cost', 'of', 'computing']},
#  {'id': 'T24',
#   'relation_type': 'data 6583 6605',
#   'arguments': ['complicated', 'algorithms']},
#  {'id': 'T25',
#   'relation_type': 'background_claim 6385 6483',
#   'arguments': ['this',
#    'category',
#    'can',
#    'generate',
#    'more',
#    'believable',
#    'animation',
#    'effects',
#    'compared',
#    'to',
#    'its',
#    'geometric',
#    'counterpart']},
#  {'id': 'T26',
#   'relation_type': 'background_claim 6662 6684',
#   'arguments': ['Pose', 'Space', 'Deformation']},
#  {'id': 'T27',
#   'relation_type': 'background_claim 6692 6855',
#   'arguments': ['combines',
#    'shape',
#    'blending',
#    'and',
#    'Skeleton',
#    'Subspace',
#    'Deformation',
#    'by',
#    'formulating',
#    'a',
#    'scattered',
#    'data',
#    'interpolation',
#    'problem',
#    'over',
#    'sculpted',
#    '(or',
#    'otherwise',
#    'obtained)',
#    'example',
#    'poses']},
#  {'id': 'T28',
#   'relation_type': 'data 6686 6691',
#   'arguments': ['[', '1', ']']},
#  {'id': 'T29',
#   'relation_type': 'background_claim 7666 7750',
#   'arguments': ['Related',
#    'research',
#    'efforts',
#    'have',
#    'improved',
#    'the',
#    'speed',
#    'and',
#    'power',
#    'of',
#    'example-based',
#    'skinning']},
#  {'id': 'T30',
#   'relation_type': 'background_claim 7759 7840',
#   'arguments': ['incorporate',
#    'linear',
#    'elements',
#    'into',
#    'RBF',
#    'to',
#    'produce',
#    'constant',
#    'changes',
#    'between',
#    'examples']},
#  {'id': 'T31',
#   'relation_type': 'data 7752 7757',
#   'arguments': ['[', '2', ']']},
#  {'id': 'T32',
#   'relation_type': 'background_claim 7848 7988',
#   'arguments': ['precompute',
#    'principal',
#    'components',
#    'of',
#    'the',
#    'deformation',
#    'influences',
#    'for',
#    'individual',
#    'kinematic',
#    'joints',
#    'instead',
#    'of',
#    'storing',
#    'displacements',
#    'for',
#    'key',
#    'poses']},
#  {'id': 'T33',
#   'relation_type': 'background_claim 7998 8078',
#   'arguments': ['enabling',
#    'realtime',
#    'rendering',
#    'large',
#    'nonlinear',
#    'finite',
#    'element',
#    'models',
#    'of',
#    'human',
#    'hands']},
#  {'id': 'T34',
#   'relation_type': 'data 7842 7847',
#   'arguments': ['[', '3', ']']},
#  {'id': 'T35',
#   'relation_type': 'background_claim 8086 8172',
#   'arguments': ['introduce',
#    'weighted',
#    'pose',
#    'space',
#    'deformation',
#    'for',
#    'deforming',
#    'realistic',
#    'models',
#    'of',
#    'human',
#    'hand']},
#  {'id': 'T36',
#   'relation_type': 'data 8080 8085',
#   'arguments': ['[', '4', ']']},
#  {'id': 'T37',
#   'relation_type': 'background_claim 8356 8447',
#   'arguments': ['these',
#    'example-based',
#    'approaches',
#    'can',
#    'be',
#    'considered',
#    'as',
#    'non-parametric',
#    'skin',
#    'deformation',
#    'methods']},
#  {'id': 'T38',
#   'relation_type': 'background_claim 8196 8297',
#   'arguments': ['identifies',
#    'statistically',
#    'relevant',
#    'bones',
#    'and',
#    'approximates',
#    'bone',
#    'transforms',
#    'from',
#    'example',
#    'mesh',
#    'animations']},
#  {'id': 'T39',
#   'relation_type': 'data 8190 8195',
#   'arguments': ['[', '5', ']']},
#  {'id': 'T40',
#   'relation_type': 'background_claim 8684 8737',
#   'arguments': ['these',
#    'have',
#    'also',
#    'seen',
#    'some',
#    'development',
#    'in',
#    'recent',
#    'years']},
#  {'id': 'T41',
#   'relation_type': 'data 8738 8743',
#   'arguments': ['[', '6', ']']},
#  {'id': 'T42',
#   'relation_type': 'data 8745 8750',
#   'arguments': ['[', '7', ']']},
#  {'id': 'T43',
#   'relation_type': 'background_claim 8870 8927',
#   'arguments': ['are',
#    'also',
#    'common',
#    'practices',
#    'in',
#    'the',
#    'entertainment',
#    'production']},
#  {'id': 'T44',
#   'relation_type': 'background_claim 8752 8785',
#   'arguments': ['Skinning', 'using', 'free', 'form', 'lattices']},
#  {'id': 'T45',
#   'relation_type': 'background_claim 8802 8814',
#   'arguments': ['NURBS', 'curves']},
#  {'id': 'T46',
#   'relation_type': 'data 8815 8821',
#   'arguments': ['[', '10', ']']},
#  {'id': 'T47',
#   'relation_type': 'data 8786 8791',
#   'arguments': ['[', '8', ']']},
#  {'id': 'T48',
#   'relation_type': 'data 8793 8798',
#   'arguments': ['[', '9', ']']},
#  {'id': 'T49',
#   'relation_type': 'own_claim 9263 9308',
#   'arguments': ['the',
#    'inverse',
#    'operation',
#    'can',
#    'improve',
#    'the',
#    'results']},
#  {'id': 'T50',
#   'relation_type': 'own_claim 9590 9619',
#   'arguments': ['inverse', 'operation', 'is', 'required']},
#  {'id': 'T51',
#   'relation_type': 'background_claim 10442 10525',
#   'arguments': ['SSD',
#    'is',
#    'widely',
#    'applied',
#    'to',
#    'interactive',
#    'applications',
#    'such',
#    'as',
#    'games',
#    'and',
#    'virtual',
#    'reality']},
#  {'id': 'T52',
#   'relation_type': 'background_claim 10531 10586',
#   'arguments': ['it',
#    'is',
#    'implemented',
#    'in',
#    'most',
#    'commercial',
#    'animation',
#    'packages']},
#  {'id': 'T53',
#   'relation_type': 'data 10411 10425',
#   'arguments': ['its', 'simplicity']},
#  {'id': 'T54',
#   'relation_type': 'data 10430 10440',
#   'arguments': ['efficiency']},
#  {'id': 'T55',
#   'relation_type': 'background_claim 12084 12179',
#   'arguments': ['SSD',
#    'is',
#    'very',
#    'popular',
#    'in',
#    'circumstances',
#    'that',
#    'require',
#    'animating',
#    'a',
#    'number',
#    'of',
#    'characters',
#    'in',
#    'real',
#    'time']},
#  {'id': 'T56',
#   'relation_type': 'data 12014 12082',
#   'arguments': ['vertex',
#    'transformations',
#    'can',
#    'be',
#    'easily',
#    'implemented',
#    'in',
#    'the',
#    'graphic',
#    'card']},
#  {'id': 'T57',
#   'relation_type': 'background_claim 12335 12494',
#   'arguments': ['the',
#    'domain',
#    'of',
#    'adjusting',
#    'one',
#    'vertex',
#    'in',
#    'this',
#    'way',
#    'is',
#    'strictly',
#    'limited',
#    'to',
#    'the',
#    'linear',
#    'subspace',
#    'formed',
#    'by',
#    'the',
#    'vertex',
#    'as',
#    'transformed',
#    'by',
#    'joints',
#    'influencing',
#    'this',
#    'vertex']},
#  {'id': 'T58',
#   'relation_type': 'background_claim 12243 12329',
#   'arguments': ['When',
#    'a',
#    'character',
#    'goes',
#    'wrong',
#    'in',
#    'some',
#    'pose,',
#    'animators',
#    'can',
#    'adjust',
#    'joint',
#    'influence',
#    'weights']},
#  {'id': 'T59',
#   'relation_type': 'background_claim 12741 12832',
#   'arguments': ['SSD',
#    'cannot',
#    'synthesize',
#    'many',
#    'parts',
#    'of',
#    'a',
#    'character',
#    'skin',
#    'involving',
#    'complicated',
#    'joint',
#    'structures']},
#  {'id': 'T60',
#   'relation_type': 'background_claim 12671 12712',
#   'arguments': ['deforming',
#    'is',
#    'limited',
#    'to',
#    'a',
#    'linear',
#    'subspace']},
#  {'id': 'T61',
#   'relation_type': 'data 12634 12639',
#   'arguments': ['[', '1', ']']},
#  {'id': 'T62',
#   'relation_type': 'background_claim 12917 13008',
#   'arguments': ['a',
#    'combination',
#    'of',
#    'SSD',
#    'and',
#    'shape',
#    'blending',
#    'providing',
#    'nice',
#    'solution',
#    'to',
#    'above',
#    'mentioned',
#    'problems']},
#  {'id': 'T63',
#   'relation_type': 'data 12908 12913',
#   'arguments': ['[', '1', ']']},
#  {'id': 'T64',
#   'relation_type': 'background_claim 14983 15062',
#   'arguments': ['PSD',
#    'and',
#    'improved',
#    'example-based',
#    'schemes',
#    'have',
#    'been',
#    'discussed',
#    'in',
#    'many',
#    'publications']},
#  {'id': 'T65',
#   'relation_type': 'data 15064 15069',
#   'arguments': ['[', '2', ']']},
#  {'id': 'T66',
#   'relation_type': 'data 15071 15076',
#   'arguments': ['[', '3', ']']},
#  {'id': 'T67',
#   'relation_type': 'data 15078 15083',
#   'arguments': ['[', '4', ']']},
#  {'id': 'T68',
#   'relation_type': 'own_claim 15086 15151',
#   'arguments': ['the',
#    'reason',
#    'why',
#    'the',
#    'inverse',
#    'should',
#    'be',
#    'performed',
#    'is',
#    'still',
#    'ambiguous']},
#  {'id': 'T69',
#   'relation_type': 'own_claim 15220 15338',
#   'arguments': ['inverting',
#    'the',
#    'SSD',
#    '(and',
#    'other',
#    'deformations)',
#    'in',
#    'order',
#    'to',
#    'interpolate',
#    'the',
#    'examples',
#    'in',
#    'the',
#    'rest',
#    'pose',
#    'is',
#    'a',
#    'the',
#    'right',
#    'choice']},
#  {'id': 'T70',
#   'relation_type': 'own_claim 15478 15498',
#   'arguments': ['it', 'is', 'an', 'improvement']},
#  {'id': 'T71',
#   'relation_type': 'own_claim 15754 15791',
#   'arguments': ['the', 'superiority', 'of', 'the', 'inverse', 'method']},
#  {'id': 'T72',
#   'relation_type': 'own_claim 16991 17058',
#   'arguments': ['SSD',
#    '−1',
#    'simply',
#    'is',
#    'the',
#    'inverse',
#    'transformation',
#    'matrix',
#    'generated',
#    'by',
#    'SSD']},
#  {'id': 'T73',
#   'relation_type': 'data 16963 16989',
#   'arguments': ['SSD', 'is', 'a', '3D', 'transformation']},
#  {'id': 'T74',
#   'relation_type': 'own_claim 17950 17980',
#   'arguments': ['the', 'inverse', 'method', 'is', 'superior']},
#  {'id': 'T75',
#   'relation_type': 'background_claim 19098 19196',
#   'arguments': ['Taking',
#    'the',
#    'model',
#    'in',
#    'rest',
#    'pose',
#    'as',
#    'an',
#    'example',
#    'is',
#    'a',
#    'common',
#    'practice',
#    'when',
#    'applying',
#    'shape',
#    'interpolation']},
#  {'id': 'T76',
#   'relation_type': 'background_claim 19204 19295',
#   'arguments': ['interpolating',
#    'effects',
#    'from',
#    'other',
#    'examples',
#    'should',
#    'not',
#    'change',
#    'the',
#    'original',
#    'model',
#    'in',
#    'rest',
#    'pose']},
#  {'id': 'T77',
#   'relation_type': 'own_claim 19334 19603',
#   'arguments': ['we',
#    'have:',
#    'ω',
#    '1x',
#    '=',
#    'φ',
#    '11',
#    '−1',
#    'd',
#    '1x',
#    '+',
#    'φ',
#    '12',
#    '−1',
#    'd',
#    '2x',
#    '=',
#    'φ',
#    '12',
#    '−1',
#    'd',
#    '2x',
#    'ω',
#    '2x',
#    '=',
#    'φ',
#    '21',
#    '−1',
#    'd',
#    '1x',
#    '+',
#    'φ',
#    '22',
#    '−1',
#    'd',
#    '2x',
#    '=',
#    'φ',
#    '22',
#    '−1',
#    'd',
#    '2x',
#    '=',
#    'd',
#    '2x',
#    'ω',
#    '1y',
#    '=',
#    'φ',
#    '11',
#    '−1',
#    'd',
#    '1y',
#    '+',
#    'φ',
#    '12',
#    '−1',
#    'd',
#    '2y',
#    '=',
#    'φ',
#    '12',
#    '−1',
#    'd',
#    '2y',
#    'ω',
#    '2y',
#    '=',
#    'φ',
#    '21',
#    '−1',
#    'd',
#    '1y',
#    '+',
#    'φ',
#    '22',
#    '−1',
#    'd',
#    '2y',
#    '=',
#    'φ',
#    '22',
#    '−1',
#    'd',
#    '2y',
#    '=',
#    'd',
#    '2y',
#    'where',
#    'φ',
#    'i',
#    '−1',
#    'j',
#    'is',
#    'the',
#    '(i,',
#    'j)th',
#    'element',
#    'of',
#    'Φ',
#    '−1']},
#  {'id': 'T78',
#   'relation_type': 'own_claim 20353 20469',
#   'arguments': ['we',
#    'simplify',
#    'SSD',
#    'as',
#    'a',
#    'rotation',
#    'transformation',
#    'ignoring',
#    'other',
#    'issues',
#    'such',
#    'as',
#    'accumulating',
#    'effects',
#    'from',
#    'the',
#    'first',
#    'joint']},
#  {'id': 'T79',
#   'relation_type': 'own_claim 20318 20351',
#   'arguments': ['only', 'the', 'second', 'joint', 'is', 'rotating']},
#  {'id': 'T80',
#   'relation_type': 'own_claim 21667 21764',
#   'arguments': ['in',
#    'forward',
#    'case,',
#    'the',
#    'direction',
#    'of',
#    'deformed',
#    'vertex',
#    'always',
#    'keeps',
#    'the',
#    'same',
#    'with',
#    'the',
#    'example',
#    'cylinder']},
#  {'id': 'T81',
#   'relation_type': 'data 21765 21777',
#   'arguments': ['(', 'figure', '4', ')']},
#  {'id': 'T82',
#   'relation_type': 'own_claim 21779 21866',
#   'arguments': ['For',
#    'inverse',
#    'PSD',
#    'however,',
#    'that',
#    'direction',
#    'is',
#    'changed',
#    'along',
#    'with',
#    'the',
#    'rotation',
#    'of',
#    'the',
#    'joint']},
#  {'id': 'T83',
#   'relation_type': 'own_claim 22106 22158',
#   'arguments': ['PSD',
#    'is',
#    'supposed',
#    'to',
#    'be',
#    'a',
#    'method',
#    'as',
#    '“local”',
#    'correction']},
#  {'id': 'T84',
#   'relation_type': 'own_claim 22172 22269',
#   'arguments': ['pose',
#    'space',
#    'should',
#    'not',
#    'be',
#    'extended',
#    'to',
#    'a',
#    'whole',
#    'space',
#    'that',
#    'has',
#    'to',
#    'incorporate',
#    'all',
#    'influenced',
#    'objects']},
#  {'id': 'T85',
#   'relation_type': 'data 22082 22104',
#   'arguments': ['a', 'matter', 'of', 'experience']},
#  {'id': 'T86',
#   'relation_type': 'own_claim 22282 22353',
#   'arguments': ['large',
#    'amount',
#    'of',
#    'unnecessary',
#    'works',
#    'of',
#    'building',
#    'examples',
#    'will',
#    'be',
#    'required']},
#  {'id': 'T87',
#   'relation_type': 'own_claim 22359 22415',
#   'arguments': ['the',
#    'distance',
#    'between',
#    'different',
#    'poses',
#    'is',
#    'also',
#    'meaningless']},
#  {'id': 'T88',
#   'relation_type': 'background_claim 23066 23128',
#   'arguments': ['most',
#    'of',
#    'which',
#    'have',
#    'been',
#    'implemented',
#    'in',
#    'most',
#    'animation',
#    'packages']},
#  {'id': 'T89',
#   'relation_type': 'background_claim 22985 23049',
#   'arguments': ['in',
#    'many',
#    'circumstances,',
#    'other',
#    'deformation',
#    'schemes',
#    'will',
#    'be',
#    'adopted']},
#  {'id': 'T90',
#   'relation_type': 'data 23058 23064',
#   'arguments': ['[', '10', ']']},
#  {'id': 'T91',
#   'relation_type': 'data 23051 23056',
#   'arguments': ['[', '9', ']']},
#  {'id': 'T92',
#   'relation_type': 'own_claim 23289 23371',
#   'arguments': ['we',
#    'can',
#    'deform',
#    'the',
#    'original',
#    'character',
#    'model',
#    'from',
#    'rest',
#    'pose',
#    'to',
#    'another',
#    'specific',
#    'pose']},
#  {'id': 'T93',
#   'relation_type': 'background_claim 25039 25152',
#   'arguments': ['One',
#    'advantage',
#    'of',
#    'Powell’s',
#    'classic',
#    'method',
#    'is',
#    'that',
#    'it',
#    'does',
#    'not',
#    'need',
#    'explicit',
#    'computation',
#    'of',
#    'the',
#    'function’s',
#    'gradient']},
#  {'id': 'T94',
#   'relation_type': 'data 25154 25160',
#   'arguments': ['[', '12', ']']},
#  {'id': 'T95',
#   'relation_type': 'own_claim 25264 25291',
#   'arguments': ['Powell’s', 'method', 'is', 'suitable']},
#  {'id': 'T96',
#   'relation_type': 'data 25170 25259',
#   'arguments': ['we',
#    'are',
#    'treating',
#    'the',
#    'skinning',
#    'operations',
#    'as',
#    'a',
#    '“black',
#    'box”,',
#    'their',
#    'gradient',
#    'is',
#    'not',
#    'available']},
#  {'id': 'T97',
#   'relation_type': 'background_claim 25659 25789',
#   'arguments': ['after',
#    'repeated',
#    'cycles',
#    'of',
#    'M',
#    'line',
#    'minimizations',
#    'on',
#    'conjugate',
#    'directions,',
#    'the',
#    'optimization',
#    'will',
#    'in',
#    'due',
#    'course',
#    'converge',
#    'to',
#    'the',
#    'minimum']},
#  {'id': 'T98',
#   'relation_type': 'data 25790 25796',
#   'arguments': ['[', '12', ']']},
#  {'id': 'T99',
#   'relation_type': 'own_claim 26918 27029',
#   'arguments': ['If',
#    'the',
#    'SSD',
#    'transformation',
#    'in',
#    'equation',
#    '1',
#    'is',
#    'singular,',
#    'some',
#    'types',
#    'of',
#    'inverse',
#    'PSD',
#    'deformation',
#    'will',
#    'not',
#    'be',
#    'possible']},
#  {'id': 'T100',
#   'relation_type': 'data 27039 27141',
#   'arguments': ['any',
#    'component',
#    'of',
#    'the',
#    'desired',
#    'deformation',
#    'that',
#    'lies',
#    'in',
#    'the',
#    'null',
#    'space',
#    'of',
#    'the',
#    'SSD',
#    'matrix',
#    'will',
#    'be',
#    'ignored']},
#  {'id': 'T101',
#   'relation_type': 'own_claim 27152 27175',
#   'arguments': ['singular', 'cases', 'are', 'rare']},
#  {'id': 'T102',
#   'relation_type': 'own_claim 27324 27415',
#   'arguments': ['it',
#    'is',
#    'possible',
#    'to',
#    'handle',
#    'these',
#    'cases',
#    'with',
#    'a',
#    'small',
#    'rearrangement',
#    'of',
#    'the',
#    'inverse',
#    'PSD',
#    'approach']},
#  {'id': 'T103',
#   'relation_type': 'data 27177 27321',
#   'arguments': ['one',
#    'example',
#    'is',
#    'a',
#    'joint',
#    'with',
#    '180',
#    'o',
#    'rotation',
#    'and',
#    'equal',
#    '2',
#    '1',
#    ',',
#    '2',
#    '1',
#    'weights',
#    'on',
#    'the',
#    'two',
#    'joint',
#    'frames,',
#    'which',
#    'is',
#    'an',
#    'unrealistic',
#    'case',
#    'of',
#    'selfintersection']},
#  {'id': 'T104',
#   'relation_type': 'own_claim 27847 27875',
#   'arguments': ['it', 'will', 'be', 'generally', 'be', 'zero']},
#  {'id': 'T105',
#   'relation_type': 'data 27823 27845',
#   'arguments': ['w', 'i', 'is', 'being', 'minimized']},
#  {'id': 'T106',
#   'relation_type': 'own_claim 27881 27992',
#   'arguments': ['will',
#    'be',
#    'non-zero',
#    'only',
#    'if',
#    'it',
#    'is',
#    'not',
#    'possible',
#    'to',
#    'obtain',
#    'the',
#    'desired',
#    'deformation',
#    'v',
#    'i',
#    'using',
#    'SKINNING',
#    'i',
#    '(v',
#    'r',
#    '+',
#    'd',
#    'i',
#    ')']},
#  {'id': 'T107',
#   'relation_type': 'own_claim 28651 28742',
#   'arguments': ['Inverse',
#    'skinning',
#    'integrates',
#    'SSD',
#    'and',
#    'shape',
#    'interpolation',
#    'more',
#    'firmly',
#    'than',
#    'its',
#    'forward',
#    'rival.']},
#  {'id': 'T108',
#   'relation_type': 'own_claim 28960 29042',
#   'arguments': ['the',
#    'inverse',
#    'approach',
#    'presents',
#    'better',
#    'performance',
#    'and',
#    'more',
#    'consistent',
#    'interpolation']},
#  {'id': 'T109',
#   'relation_type': 'data 29045 29066',
#   'arguments': ['Figure', '7', 'to', 'Figure', '10']},
#  {'id': 'T110',
#   'relation_type': 'own_claim 28758 28948',
#   'arguments': ['the',
#    'direction',
#    'of',
#    'deformed',
#    'vertex',
#    'in',
#    'inverse',
#    'skinning',
#    'is',
#    'linearly',
#    'proportional',
#    'to',
#    'joint',
#    'rotations',
#    'in',
#    'a',
#    'simplified',
#    'example,',
#    'while',
#    'the',
#    'forward',
#    'PSD',
#    'does',
#    'not',
#    'incorporate',
#    'the',
#    'direction',
#    'information']},
#  {'id': 'T111',
#   'relation_type': 'own_claim 29268 29315',
#   'arguments': ['the',
#    'minimizing',
#    'process',
#    'will',
#    'introduce',
#    'more',
#    'cost']},
#  {'id': 'T112',
#   'relation_type': 'own_claim 29640 29689',
#   'arguments': ['The',
#    'cost',
#    'of',
#    'the',
#    'inverse',
#    'operation',
#    'is',
#    'not',
#    'critical']},
#  {'id': 'T113',
#   'relation_type': 'own_claim 29706 29735',
#   'arguments': ['it', 'is', 'a', 'one', 'time', '“setup”', 'cost']},
#  {'id': 'T114',
#   'relation_type': 'own_claim 29741 29845',
#   'arguments': ['the',
#    'compute',
#    'time',
#    'is',
#    'insignificant',
#    'compared',
#    'to',
#    'the',
#    'human',
#    'time',
#    'required',
#    'to',
#    'sculpt',
#    'the',
#    'desired',
#    'deformations']},
#  {'id': 'T115',
#   'relation_type': 'data 2835 2853',
#   'arguments': ['a', 'frame', 'goes', 'wrong']},
#  {'id': 'T116',
#   'relation_type': 'data 6364 6383',
#   'arguments': ['physical', 'principles']},
#  {'id': 'T117',
#   'relation_type': 'data 2727 2753',
#   'arguments': ['the', 'model', 'is', 'very', 'detailed']},
#  {'id': 'T118',
#   'relation_type': 'data 2758 2818',
#   'arguments': ['playback',
#    'of',
#    'animation',
#    'becomes',
#    'quite',
#    'heavy',
#    'and',
#    'time',
#    'consuming']},
#  {'id': 'T119',
#   'relation_type': 'background_claim 3993 4044',
#   'arguments': ['For',
#    'those',
#    'applications',
#    'that',
#    'require',
#    'visual',
#    'fidelity']},
#  {'id': 'T120',
#   'relation_type': 'background_claim 4062 4098',
#   'arguments': ['SSD', 'serves', 'only', 'as', 'a', 'basic', 'framework']},
#  {'id': 'T121',
#   'relation_type': 'background_claim 4439 4535',
#   'arguments': ['PSD',
#    'smoothly',
#    'interpolates',
#    'these',
#    'meshes',
#    'in',
#    'pose',
#    'space',
#    'and',
#    'produces',
#    'visually',
#    'attractive',
#    'animations']},
#  {'id': 'T122',
#   'relation_type': 'background_claim 4951 4989',
#   'arguments': ['Besides', 'SSD,', 'other', 'skinning', 'approaches']},
#  {'id': 'T123',
#   'relation_type': 'background_claim 5041 5060',
#   'arguments': ['can', 'also', 'be', 'applied']},
#  {'id': 'T124',
#   'relation_type': 'data 4998 5012',
#   'arguments': ['rigid', 'skinning']},
#  {'id': 'T125',
#   'relation_type': 'data 5014 5035',
#   'arguments': ['Free', 'Form', 'Deformation']},
#  {'id': 'T126',
#   'relation_type': 'background_claim 6265 6356',
#   'arguments': ['physical',
#    'modelling',
#    'and',
#    'animation',
#    'is',
#    'another',
#    'field',
#    'providing',
#    'realistic',
#    'character',
#    'simulations']},
#  {'id': 'T127',
#   'relation_type': 'background_claim 8578 8682',
#   'arguments': ['Simpler',
#    'parametric',
#    'skinning',
#    'approaches',
#    '(of',
#    'which',
#    'SSD',
#    'is',
#    'the',
#    'prototype)',
#    'have',
#    'a',
#    'fixed',
#    'number',
#    'of',
#    'parameters']},
#  {'id': 'T128',
#   'relation_type': 'own_claim 9346 9441',
#   'arguments': ['the',
#    'direction',
#    'of',
#    'deformed',
#    'vertices',
#    'from',
#    'inverse',
#    'skinning',
#    'is',
#    'a',
#    'linear',
#    'function',
#    'of',
#    'joint',
#    'rotation']},
#  {'id': 'T129',
#   'relation_type': 'own_claim 9449 9510',
#   'arguments': ['in',
#    'the',
#    'forward',
#    'approach,',
#    'that',
#    'direction',
#    'is',
#    'kept',
#    'as',
#    'a',
#    'constant']},
#  {'id': 'T130',
#   'relation_type': 'own_claim 9695 9848',
#   'arguments': ['propose',
#    'a',
#    'unified',
#    'framework',
#    'which',
#    'can',
#    'be',
#    'implemented',
#    'on',
#    'high-end',
#    'commercial',
#    'packages',
#    'while',
#    'allowing',
#    'any',
#    'proprietary',
#    'skinning',
#    'operators',
#    'to',
#    'be',
#    'incorporated']},
#  {'id': 'T131',
#   'relation_type': 'background_claim 10115 10276',
#   'arguments': ['Skeleton',
#    'Subspace',
#    'Deformation',
#    '(SSD)',
#    'is',
#    'a',
#    'basic',
#    'algorithm',
#    'that',
#    'is',
#    'used',
#    'to',
#    'define',
#    'how',
#    'the',
#    'character',
#    'surface',
#    'deforms',
#    'following',
#    'movements',
#    'of',
#    'its',
#    'underlying',
#    'skeletons']},
#  {'id': 'T132',
#   'relation_type': 'data 10309 10315',
#   'arguments': ['[', '11', ']']},
#  {'id': 'T133',
#   'relation_type': 'data 10949 10987',
#   'arguments': ['SSD', 'is', 'adopted', 'to', 'define', 'this', 'relation']},
#  {'id': 'T134',
#   'relation_type': 'background_claim 10989 11158',
#   'arguments': ['each',
#    'vertex',
#    'or',
#    'control',
#    'point',
#    'of',
#    'the',
#    'character',
#    'surface',
#    'is',
#    'provided',
#    'with',
#    'a',
#    'list',
#    'of',
#    'joints,',
#    'that',
#    'will',
#    'influence',
#    'it,',
#    'along',
#    'with',
#    'the',
#    'weight',
#    'indicating',
#    'the',
#    'amount',
#    'of',
#    'influence']},
#  {'id': 'T135',
#   'relation_type': 'background_claim 11192 11326',
#   'arguments': ['the',
#    'position',
#    'of',
#    'a',
#    'vertex',
#    'in',
#    'the',
#    'animated',
#    'pose',
#    'is',
#    'the',
#    'result',
#    'of',
#    'weighted',
#    'linear',
#    'blending',
#    'of',
#    'its',
#    'transformation',
#    'by',
#    'each',
#    'associated',
#    'joint']},
#  {'id': 'T136',
#   'relation_type': 'data 11165 11190',
#   'arguments': ['the', 'character', 'is', 'animated']},
#  {'id': 'T137',
#   'relation_type': 'background_claim 12572 12615',
#   'arguments': ['The',
#    'famous',
#    'SSD',
#    'problem',
#    'of',
#    '“collapsed',
#    'elbow”']},
#  {'id': 'T138',
#   'relation_type': 'data 13915 13942',
#   'arguments': ['sculpted', 'in', 'N', 'example', 'poses']},
#  {'id': 'T139',
#   'relation_type': 'data 13900 13910',
#   'arguments': ['a', 'vertex', 'v']},
#  {'id': 'T140',
#   'relation_type': 'own_claim 13949 14047',
#   'arguments': ['there',
#    'are',
#    'N',
#    'delta',
#    'd',
#    'i',
#    ',',
#    'i',
#    '=',
#    '0,',
#    '.',
#    '.',
#    '.',
#    ',',
#    'N',
#    '−',
#    '1',
#    'corresponding',
#    'to',
#    'each',
#    'pose',
#    'x',
#    'i',
#    ',',
#    'i',
#    '=',
#    '0,',
#    '.',
#    '.',
#    '.',
#    ',',
#    'N',
#    '−',
#    '1']},
#  {'id': 'T141',
#   'relation_type': 'own_claim 15515 15545',
#   'arguments': ['SSD', 'as', 'the', 'underlying', 'skinning']},
#  {'id': 'T142',
#   'relation_type': 'own_claim 15553 15632',
#   'arguments': ['an',
#    'explicit',
#    'form',
#    'of',
#    'basic',
#    'skinning',
#    'can',
#    'help',
#    'to',
#    'simplify',
#    'our',
#    'task',
#    'of',
#    'explanation']},
#  {'id': 'T143',
#   'relation_type': 'data 19004 19059',
#   'arguments': ['in',
#    'the',
#    'rest',
#    'pose,',
#    'we',
#    'didn’t',
#    'generate',
#    'any',
#    'movement',
#    'for',
#    'v']},
#  {'id': 'T144',
#   'relation_type': 'own_claim 19067 19096',
#   'arguments': ['d',
#    '1',
#    '=',
#    '[d',
#    '1x',
#    ',',
#    'd',
#    '1y',
#    ']',
#    '=',
#    '[0,',
#    '0]']},
#  {'id': 'T145',
#   'relation_type': 'data 19308 19333',
#   'arguments': ['by', 'solving', 'above', 'equation']},
#  {'id': 'T146',
#   'relation_type': 'data 19613 19618',
#   'arguments': ['i', '=', 'j']},
#  {'id': 'T147',
#   'relation_type': 'own_claim 19620 19632',
#   'arguments': ['φ', 'i', '−1', 'j', '=', '1']},
#  {'id': 'T148',
#   'relation_type': 'own_claim 20030 20137',
#   'arguments': ['this',
#    'angle',
#    'α',
#    'p',
#    'is',
#    'a',
#    'constant',
#    'and',
#    'depends',
#    'only',
#    'on',
#    'the',
#    'value',
#    'of',
#    'delta',
#    'in',
#    'the',
#    'second',
#    'pose',
#    'd',
#    '2',
#    '=',
#    '[d',
#    '2x',
#    ',',
#    'd',
#    '2y',
#    ']']},
#  {'id': 'T149',
#   'relation_type': 'own_claim 19817 20018',
#   'arguments': ['tan',
#    'α',
#    'p',
#    '=',
#    'd',
#    'd',
#    'x',
#    'y',
#    '=',
#    'ω',
#    'ω',
#    '1x',
#    '1y',
#    'φ',
#    'φ',
#    '(x',
#    '(x',
#    '−',
#    '−',
#    'x',
#    'x',
#    '1',
#    '1',
#    ')',
#    ')',
#    '+',
#    '+',
#    'ω',
#    'ω',
#    '2y',
#    '2x',
#    'φ',
#    'φ',
#    '(x',
#    '(x',
#    '−',
#    '−',
#    'x',
#    'x',
#    '2',
#    '2',
#    ')',
#    ')',
#    '=',
#    'φ',
#    'φ',
#    '12',
#    '12',
#    '−1',
#    '−1',
#    'd',
#    'd',
#    '2x',
#    '2y',
#    'φ',
#    'φ',
#    '(x',
#    '(x',
#    '−',
#    '−',
#    'x',
#    'x',
#    '1',
#    '1',
#    ')',
#    ')',
#    '+',
#    '+',
#    'd',
#    'd',
#    '2x',
#    '2y',
#    'φ',
#    'φ',
#    '(x',
#    '(x',
#    '−',
#    '−',
#    'x',
#    'x',
#    '2',
#    '2',
#    ')',
#    ')',
#    '=',
#    'd',
#    '2y',
#    'd',
#    '2x']},
#  {'id': 'T150',
#   'relation_type': 'own_claim 19683 19700',
#   'arguments': ['tan', 'α', 'p', '=', 'd', 'd', 'x', 'y']},
#  {'id': 'T151',
#   'relation_type': 'own_claim 21868 21920',
#   'arguments': ['The',
#    'case',
#    'described',
#    'above',
#    'is',
#    'quite',
#    'common',
#    'in',
#    'practice']},
#  {'id': 'T152',
#   'relation_type': 'data 21926 21973',
#   'arguments': ['animating',
#    'shoulder,',
#    'elbow,',
#    'knee,',
#    'hip-bone,',
#    'neck']},
#  {'id': 'T153',
#   'relation_type': 'own_claim 21980 22058',
#   'arguments': ['All',
#    'these',
#    'parts',
#    'would',
#    'rotate',
#    'from',
#    'the',
#    'rest',
#    'pose',
#    'with',
#    'some',
#    'angle',
#    'to',
#    'other',
#    'poses']},
#  {'id': 'T154',
#   'relation_type': 'own_claim 23151 23225',
#   'arguments': ['a',
#    'unified',
#    'framework',
#    'in',
#    'which',
#    'no',
#    'explicit',
#    'inverse',
#    'operation',
#    'is',
#    'necessitated']},
#  {'id': 'T155',
#   'relation_type': 'data 23233 23288',
#   'arguments': ['a',
#    'basic',
#    'skinning',
#    'method',
#    'supported',
#    'by',
#    'animation',
#    'packages']},
#  {'id': 'T156',
#   'relation_type': 'own_claim 23494 23537',
#   'arguments': ['v',
#    'i',
#    't',
#    '=',
#    'v',
#    'i',
#    '+',
#    'd',
#    'i',
#    '=',
#    'SKINNING',
#    'i',
#    '(v',
#    'r',
#    ')',
#    '+',
#    'd',
#    'i']},
#  {'id': 'T157',
#   'relation_type': 'own_claim 23399 23492',
#   'arguments': ['we',
#    'need',
#    'to',
#    'replace',
#    'SSD',
#    'with',
#    'SKINNING',
#    'in',
#    'the',
#    'inverse',
#    'skinning',
#    'algorithm',
#    'as',
#    'such',
#    'for',
#    'equation',
#    '4']},
#  {'id': 'T158',
#   'relation_type': 'data 23376 23397',
#   'arguments': ['the', 'more', 'general', 'case']},
#  {'id': 'T159',
#   'relation_type': 'own_claim 23613 23765',
#   'arguments': ['To',
#    'find',
#    'delta',
#    'd',
#    'i',
#    'in',
#    'the',
#    'rest',
#    'pose:',
#    'v',
#    'i',
#    '=',
#    'SKINNING',
#    'i',
#    '(v',
#    'r',
#    ')',
#    '+',
#    'd',
#    'i',
#    '=',
#    'SKINNING',
#    'i',
#    '(v',
#    'r',
#    '+',
#    'd',
#    'i',
#    ')',
#    'we',
#    'can',
#    'setup',
#    'a',
#    'minimization',
#    'problem',
#    'to',
#    'minimize',
#    'the',
#    'function']},
#  {'id': 'T160',
#   'relation_type': 'own_claim 24028 24110',
#   'arguments': ['This',
#    'function',
#    'can',
#    'be',
#    'given',
#    'to',
#    'Powell’s',
#    'method',
#    'to',
#    'find',
#    'd',
#    'i',
#    'at',
#    'the',
#    'minimum',
#    'of',
#    'f',
#    '(d',
#    ')']},
#  {'id': 'T161',
#   'relation_type': 'data 24112 24153',
#   'arguments': ['For',
#    'each',
#    'example',
#    'pose',
#    'P',
#    'i',
#    ',',
#    'we',
#    'have',
#    'a',
#    'd',
#    'i']},
#  {'id': 'T162',
#   'relation_type': 'own_claim 24161 24270',
#   'arguments': ['we',
#    'can',
#    'apply',
#    'radial',
#    'basis',
#    'function',
#    'to',
#    'd',
#    'i',
#    '(i',
#    '=',
#    '0',
#    '.',
#    '.',
#    '.',
#    'n',
#    '−',
#    '1)',
#    'in',
#    'pose',
#    'space',
#    'to',
#    'obtain',
#    'ω',
#    'i',
#    '(i',
#    '=',
#    '0',
#    '.',
#    '.',
#    '.',
#    'n',
#    '−',
#    '1)']},
#  {'id': 'T163',
#   'relation_type': 'own_claim 25293 25398',
#   'arguments': ['Minimizing',
#    'the',
#    'function',
#    'f',
#    '(d',
#    ')',
#    'in',
#    'a',
#    'particular',
#    'direction',
#    'is',
#    'actually',
#    'minimization',
#    'problem',
#    'of',
#    'one',
#    'variable']},
#  {'id': 'T164',
#   'relation_type': 'background_claim 25440 25556',
#   'arguments': ['Powell’s',
#    'idea',
#    'is',
#    'trying',
#    'to',
#    'find',
#    'each',
#    'minimum',
#    'of',
#    'function',
#    'f',
#    '(d',
#    ')',
#    'in',
#    'different',
#    'direction',
#    'until',
#    'f',
#    '(d',
#    ')',
#    'stops',
#    'decreasing']},
#  {'id': 'T165',
#   'relation_type': 'background_claim 25558 25629',
#   'arguments': ['How',
#    'to',
#    'choose',
#    'the',
#    'next',
#    'direction',
#    'is',
#    'the',
#    'main',
#    'concern',
#    'of',
#    'Powell’s',
#    'method']},
#  {'id': 'T166',
#   'relation_type': 'background_claim 26052 26159',
#   'arguments': ['In',
#    'Maya,',
#    '“tweaking”',
#    'is',
#    'a',
#    'procedure',
#    'adding',
#    'delta',
#    'values',
#    'to',
#    'original',
#    'surface',
#    'vertices',
#    'before',
#    'any',
#    'deformations']},
#  {'id': 'T167',
#   'relation_type': 'background_claim 26161 26251',
#   'arguments': ['It',
#    'is',
#    'actu-',
#    'ally',
#    'Maya’s',
#    'form',
#    'of',
#    'rest-pose',
#    'editing',
#    'for',
#    'their',
#    'built-in',
#    'deformation',
#    'operators']},
#  {'id': 'T168',
#   'relation_type': 'own_claim 26280 26323',
#   'arguments': ['the',
#    'whole',
#    'system',
#    'is',
#    'divided',
#    'into',
#    'two',
#    'phases']},
#  {'id': 'T169',
#   'relation_type': 'data 26269 26277',
#   'arguments': ['Figure', '6']},
#  {'id': 'T170',
#   'relation_type': 'own_claim 26325 26414',
#   'arguments': ['The',
#    'first',
#    'phase',
#    'is',
#    'to',
#    'find',
#    'each',
#    'delta',
#    'in',
#    'the',
#    'rest',
#    'pose',
#    'corresponding',
#    'to',
#    'each',
#    'example',
#    'pose']},
#  {'id': 'T171',
#   'relation_type': 'own_claim 26570 26665',
#   'arguments': ['the',
#    'second',
#    'phase',
#    'that',
#    'is',
#    'a',
#    'linear',
#    'system',
#    'performing',
#    'RBF',
#    'interpolation',
#    'to',
#    'obtain',
#    'the',
#    'PSD',
#    'weights']},
#  {'id': 'T172',
#   'relation_type': 'own_claim 27753 27791',
#   'arguments': ['only', 'minimal', 'code', 'changed', 'are', 'required']},
#  {'id': 'T173',
#   'relation_type': 'own_claim 27596 27745',
#   'arguments': ['The',
#    'final',
#    'synthesis',
#    'is',
#    'then',
#    'v',
#    'x',
#    '=',
#    'SKINNING(v',
#    'r',
#    '+',
#    'd',
#    'x',
#    ')',
#    '+',
#    'w',
#    'x',
#    'where',
#    'w',
#    'x',
#    'is',
#    'interpolated',
#    'after',
#    'SKINNING',
#    'by',
#    'applying',
#    'the',
#    'same',
#    'RBF',
#    'scheme',
#    'as',
#    'used',
#    'for',
#    'd',
#    'x']},
#  {'id': 'T174',
#   'relation_type': 'data 28012 28045',
#   'arguments': ['the', 'SSD', 'transform', 'is', 'nearsingular']},
#  {'id': 'T175',
#   'relation_type': 'own_claim 28047 28143',
#   'arguments': ['the',
#    'solved',
#    'd',
#    'i',
#    'can',
#    'be',
#    'much',
#    'large',
#    'than',
#    'other',
#    'd',
#    'k',
#    ',',
#    'which',
#    'can',
#    'result',
#    'in',
#    'poorly',
#    'posed',
#    'interpolation']},
#  {'id': 'T176',
#   'relation_type': 'own_claim 29881 29918',
#   'arguments': ['the', 'synthesis', 'is', 'potentially', 'realtime']},
#  {'id': 'T177',
#   'relation_type': 'own_claim 29925 29971',
#   'arguments': ['no',
#    'extra',
#    'computing',
#    'is',
#    'involved',
#    'in',
#    'this',
#    'process']},
#  {'id': 'T178',
#   'relation_type': 'data 29852 29879',
#   'arguments': ['the', 'linear', 'system', 'is', 'solved']},
#  {'id': 'T179',
#   'relation_type': 'data 5433 5493',
#   'arguments': ['only',
#    'one',
#    'joint',
#    'rotation',
#    'and',
#    'two',
#    'example',
#    'poses',
#    'are',
#    'considered']},
#  {'id': 'T180',
#   'relation_type': 'background_claim 3309 3338',
#   'arguments': ['A', 'nice', 'review', 'of', 'SSD', 'is', 'given']},
#  {'id': 'T181', 'relation_type': 'data 3344 3345', 'arguments': ['1']},
#  {'id': 'T182',
#   'relation_type': 'data 2906 2924',
#   'arguments': ['resculpting', 'models']},
#  {'id': 'T183',
#   'relation_type': 'data 2928 2948',
#   'arguments': ['re-rigging', 'skeletons']}]

# %%
import nltk

def read_ann_file(ann_file_path):
    annotations = []
    
    with open(ann_file_path, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split('\t')
            
            if len(parts) == 2:
                # Entity annotation (e.g., T1 Person 0 4 John)
                annotation_id, annotation_details = parts
                annotation_details_parts = annotation_details.split()
                
                # Skip lines that don't have exactly 4 parts
                if len(annotation_details_parts) != 4:
                    continue
                
                entity_type, start, end, text = annotation_details_parts
                annotations.append({
                    "id": annotation_id,
                    "type": entity_type,
                    "start": int(start),
                    "end": int(end),
                    "text": text
                })
            elif len(parts) == 3:
                # Relation annotation (e.g., R1 Located_in Arg1:T1 Arg2:T2)
                annotation_id, relation_type, args = parts
                arguments = args.split()
                annotations.append({
                    "id": annotation_id,
                    "relation_type": relation_type,
                    "arguments": arguments
                })
    
    return annotations

# %%
file="A01.ann"
ann=read_ann_file(file)
